# %% [markdown]
# В этом конкурсе ваша задача - разработать модель для предсказания успешности стартапа (закроется или нет)
#
# Данные
# Датасет состоит из двух файлов: тренировочный набор (около 53к записей) и тестовый набор (около 13к записей). Тренировочный набор содержит целевой признак status, указывающий на то, закрылся стартап или продолжает действовать. Временной период - '1970-01-01' по '2018-01-01'. Дата формирования выгрузки - '2018-01-01'

# %% [markdown]
# Описание полей данных
# name - Название стартапа
# category_list - Список категорий, к которым относится стартап
# funding_total_usd - Общая сумма финансирования в USD
# status - Статус стартапа (закрыт или действующий)
# country_code - Код страны
# state_code - Код штата
# region - Регион
# city - Город
# funding_rounds - Количество раундов финансирования
# founded_at - Дата основания
# first_funding_at - Дата первого раунда финансирования
# last_funding_at - Дата последнего раунда финансирования
# closed_at - Дата закрытия стартапа (если применимо)
# lifetime - Время существования стартапа в днях

# %% [markdown]
# ## Введение

# %% [markdown]
# - Цель проекта разработать модель для предсказания успешности стартапа (закроется или нет)
# - Данные состоят из 2х файлов, тренировочный набор (около 53к записей) и тестовый набор (около 13к записей)
# - Проект состоит из нескольких частей:
#   - предобработка данных
#   - исследовательский анализ данных
#   - создание синтетических входных признаков
#   - корреляционный анализ Фик и отбор признкаков
#   - подбор модели МО на тренировочном наборе с перебором параметров и моделей в пайплайне. Метрика качества F1
#   - формирование прогноза для тестовой выборки лучшей моделью

# %%
# !pip install requests
# !pip install fuzzywuzzy[speedup]
# !pip install pycountry
##!pip install --upgrade certifi
# !pip install kaggle
# !pip install catboost
# Out:
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.8.30)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fuzzywuzzy[speedup] in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from fuzzywuzzy[speedup]) (0.26.0)
# Requirement already satisfied: Levenshtein==0.26.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.26.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from Levenshtein==0.26.0->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.10.1)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pycountry in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (24.6.1)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: kaggle in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (2.2.1)
# Requirement already satisfied: bleach in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from tqdm->kaggle) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: catboost in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.2.7)
# Requirement already satisfied: graphviz in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (3.8.4)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.14.0)
# Requirement already satisfied: plotly in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from plotly->catboost) (9.0.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from collections import Counter
import pycountry
import numpy as np
import phik

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV, StratifiedKFold 
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer, KNNImputer
from catboost import CatBoostClassifier
from sklearn.metrics import f1_score, precision_score, recall_score

# %% [markdown]
# ## Загрузка данных

# %%
train = pd.read_csv('./kaggle_startups_train_28062024.csv')
test = pd.read_csv('./kaggle_startups_test_28062024.csv')

# %%
train.head()
# Out:
#                      name                          category_list  \
# 0               Lunchgate        Online Reservations|Restaurants
# 1                 EarLens  Manufacturing|Medical|Medical Devices
# 2  Reviva Pharmaceuticals                          Biotechnology
# 3    Sancilio and Company                            Health Care
# 4     WireTough Cylinders                          Manufacturing
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds  founded_at first_funding_at last_funding_at  \
# 0        Zürich               2  2009-10-17       2011-05-01      2014-12-01
# 1  Redwood City               4  2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3  2006-01-01       2012-08-20      2014-07-02
# 3           NaN               3  2004-01-01       2011-09-01      2014-07-18
# 4       Bristol               1  2010-05-12       2012-02-01      2012-02-01
#
#   closed_at
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
test.head()
# Out:
#                      name                   category_list  funding_total_usd  \
# 0              Crystalsol                Clean Technology          2819200.0
# 1        JBI Fish & Wings                     Hospitality                NaN
# 2                COINPLUS                         Finance           428257.0
# 3  Imagine Communications  Software|Video|Video Streaming         34700000.0
# 4                   DNA13                        Software          4530000.0
#
#   country_code state_code            region              city  funding_rounds  \
# 0          NIC         17               NaN               NaN               1
# 1          USA         TN        TN - Other          Humboldt               1
# 2          LUX          3  Esch-sur-alzette  Esch-sur-alzette               2
# 3          USA         CA         San Diego         San Diego               4
# 4          CAN         ON            Ottawa            Ottawa               1
#
#   first_funding_at last_funding_at  lifetime
# 0       2009-07-01      2009-07-01      3501
# 1       2010-07-28      2010-07-28      2717
# 2       2014-05-15      2014-09-18      1295
# 3       2005-01-01      2010-04-20      4748
# 4       2007-05-08      2007-05-08      6209

# %% [markdown]
# ## Предобработка данных

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  object
#  10  first_funding_at   52516 non-null  object
#  11  last_funding_at    52516 non-null  object
#  12  closed_at          4917 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# __Приведем поля с датами к корректоному формату__

# %%
for i in ['founded_at', 'first_funding_at', 'last_funding_at', 'closed_at']:
    train[i] = pd.to_datetime(train[i], errors='coerce')

# %%
for i in ['first_funding_at', 'last_funding_at']:
    test[i] = pd.to_datetime(test[i], errors='coerce')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  datetime64[ns]
#  10  first_funding_at   52516 non-null  datetime64[ns]
#  11  last_funding_at    52516 non-null  datetime64[ns]
#  12  closed_at          4917 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(1), int64(1), object(7)
# memory usage: 5.2+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  datetime64[ns]
#  9   last_funding_at    13125 non-null  datetime64[ns]
#  10  lifetime           13125 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# __Проверим датасеты на явные дубли__

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# __Явные дубли отсутствуют__

# %%
train[train['name'].isna()]
# Out:
#      name category_list  funding_total_usd  status country_code state_code  \
# 3291  NaN      Startups            25000.0  closed          USA         OR
#
#                 region      city  funding_rounds founded_at first_funding_at  \
# 3291  Portland, Oregon  Portland               1 2011-10-01       2012-03-01
#
#      last_funding_at  closed_at
# 3291      2012-03-01 2013-06-03

# %%
train['name'].nunique()
# Out:
# 52515

# %%
test['name'].nunique()
# Out:
# 13125

# %% [markdown]
# __У одного стартапа в трейн не указано имя. В остальном имена уникальные__

# %%
train.category_list.isna().sum()
# Out:
# 2465

# %%
train[train['category_list'].isna()].head()
# Out:
#                                 name category_list  funding_total_usd  \
# 12                    Iberic Premium           NaN           107239.0
# 16                          Salesjob           NaN                NaN
# 24                           Savasti           NaN                NaN
# 26  The Center from Health Promotion           NaN         10000000.0
# 64                Seamless Logistics           NaN                NaN
#
#        status country_code state_code region city  funding_rounds founded_at  \
# 12     closed          NaN        NaN    NaN  NaN               1 2013-07-26
# 16     closed          NaN        NaN    NaN  NaN               1 2013-01-01
# 24     closed          NaN        NaN    NaN  NaN               1 2015-01-01
# 26  operating          NaN        NaN    NaN  NaN               1 2002-04-21
# 64  operating          NaN        NaN    NaN  NaN               1 2009-02-22
#
#    first_funding_at last_funding_at  closed_at
# 12       2014-06-01      2014-06-01 2015-07-10
# 16       2013-10-22      2013-10-22 2015-08-11
# 24       2015-01-01      2015-01-01 2016-11-03
# 26       2003-11-12      2003-11-12        NaT
# 64       2011-02-01      2011-02-01        NaT

# %% [markdown]
# __В трейн и в тест есть ряд компаний без указанных категорий.__
# - Проверил базу данных с стартапами CrunchBase, к сожалению, на примере Seamless Logistics, The Center from Health Promotion founded_at из датасетов не совпадает с указанным на сайте, а Savasti совпадает.
# - API подключить не удалось, ошибка корректности ключа user. Ниже представлен код попытки
# - Заполнить пропуски в категориях не представляется возможным

# %%
#api_key = '46fd3d384bda4c87a1da5fa7f326f16d'
#organization_name = 'savasti'
#url = f"https://api.crunchbase.com/v3.1/organizations/{organization_name}?user_key={api_key}"

# Make the API request
#response = requests.get(url)

# Handle the response
#if response.status_code == 200:
#    data = response.json()  # Parse JSON data from the response
#    print(data)             # Print or process the retrieved data
#elif response.status_code == 401:
#    print("Error 401: Unauthorized. Check if your API key is correct.")
#else:
#    print(f"Error: {response.status_code}")

# %%
train.category_list.nunique()
# Out:
# 22105

# %%
test.category_list.nunique()
# Out:
# 6206

# %%
category_list = sorted(train['category_list'].dropna().unique().tolist())
category_list
# Out:
# ['3D',
#  '3D Printing',
#  '3D Printing|3D Technology',
#  '3D Printing|3D Technology|Android|Artificial Intelligence|Drones|Enterprise Application|Entertainment|Entrepreneur|Games|Lasers|Mobile|Open Source|Robotics|Telecommunications',
#  '3D Printing|3D Technology|Android|Games|iOS|Mobile|Mobile Games|Mobile Software Tools|Serious Games|Tablets|Video Games',
#  '3D Printing|3D Technology|Audio|Mass Customization',
#  '3D Printing|3D Technology|CAD|Cloud Gaming|Printing',
#  '3D Printing|3D Technology|Consumer Electronics',
#  '3D Printing|3D Technology|Creative Industries',
#  '3D Printing|3D Technology|DIY|Printing|Software',
#  '3D Printing|3D Technology|Education',
#  '3D Printing|3D Technology|Graphics',
#  '3D Printing|3D Technology|Manufacturing|Photography',
#  '3D Printing|3D Technology|Mobile Games',
#  '3D Printing|3D Technology|Startups',
#  '3D Printing|Advanced Materials|Electric Vehicles|Energy|Hardware|Health Care|High Tech|Incubators|Internet of Things|Medical Devices|Robotics|Startups',
#  '3D Printing|Advertising|Augmented Reality|Digital Entertainment|Games|Hardware + Software|Internet of Things|Location Based Services|M2M|Mobile|Mobile Games|Open Source|Teaching STEM Concepts|Video Streaming',
#  '3D Printing|Advertising|Digital Media',
#  '3D Printing|Architecture|Bitcoin|Construction|Crowdfunding|Cryptocurrency|FinTech|Real Estate',
#  '3D Printing|Architecture|Digital Entertainment|Video Games',
#  '3D Printing|Art|Beauty|Fashion',
#  '3D Printing|Bio-Pharm|Biotechnology',
#  '3D Printing|Biotechnology|GreenTech',
#  '3D Printing|Biotechnology|Health and Wellness',
#  '3D Printing|Biotechnology|mHealth',
#  '3D Printing|Business Services|Software',
#  '3D Printing|Collaborative Consumption|Local|Marketplaces',
#  '3D Printing|Consumer Electronics',
#  '3D Printing|Consumer Electronics|Internet of Things',
#  '3D Printing|Consumer Goods|E-Commerce',
#  '3D Printing|Crowdfunding|Crowdsourcing|Education|Hardware + Software|Internet of Things|Local|Manufacturing|New Product Development|Open Source',
#  '3D Printing|Design|Personalization|Technology',
#  '3D Printing|Digital Signage|Printing',
#  '3D Printing|E-Commerce|Fashion',
#  '3D Printing|E-Commerce|Fashion|Jewelry|Marketplaces',
#  '3D Printing|E-Commerce|Hardware|Internet|Manufacturing|Product Design',
#  '3D Printing|E-Commerce|Jewelry|PaaS',
#  '3D Printing|E-Commerce|Manufacturing',
#  '3D Printing|Early-Stage Technology|Industrial Automation',
#  '3D Printing|Education',
#  '3D Printing|Electronics|Printing',
#  '3D Printing|Engineering Firms|Innovation Engineering',
#  '3D Printing|Fashion|Fitness|Health and Wellness|Wearables',
#  '3D Printing|Games|Marketplaces|Online Gaming|Video Games',
#  '3D Printing|Hardware + Software',
#  '3D Printing|Health Care|Medical',
#  '3D Printing|Health and Wellness|Health Care',
#  '3D Printing|Industrial Automation|New Product Development|Open Source',
#  '3D Printing|Industrial|Product Design',
#  '3D Printing|Information Technology|Robotics',
#  '3D Printing|Internet|Publishing',
#  '3D Printing|Kids|Parenting',
#  '3D Printing|Manufacturing',
#  '3D Printing|Manufacturing|Marketplaces',
#  '3D Printing|Manufacturing|Material Science',
#  '3D Printing|Manufacturing|Product Design',
#  '3D Printing|Printing|Technology',
#  '3D Printing|Retail|Technology',
#  '3D Printing|SaaS|Video Games',
#  '3D Printing|Software',
#  '3D Printing|iPad|Kids',
#  '3D Technology',
#  '3D Technology|Application Platforms|Big Data Analytics|Energy IT|Industrial|Internet of Things|Mobile|Open Source',
#  '3D Technology|Apps|Mobile',
#  '3D Technology|Architecture|Building Products|CAD',
#  '3D Technology|Audio|Electronics|Manufacturing|Optimization',
#  '3D Technology|Augmented Reality|Computers|Computer Vision|Enterprise Software|Human Computer Interaction|Mobile|Predictive Analytics|Software|Speech Recognition|Tablets|User Experience Design',
#  '3D Technology|Augmented Reality|E-Commerce Platforms|Games|Machine Learning',
#  '3D Technology|Augmented Reality|Education|Health Care',
#  '3D Technology|CAD|Cloud Computing|Engineering Firms|High Tech|Internet|Product Design|Simulation|Software|Web Tools',
#  '3D Technology|Chat|Messaging|Real Time|Social Media',
#  '3D Technology|Cloud Computing|Fashion|Retail|SaaS',
#  '3D Technology|Computer Vision|Semiconductors',
#  '3D Technology|Consumers|Creative Industries',
#  '3D Technology|Design|Internet|Real Time',
#  '3D Technology|Developer APIs|Gamification',
#  '3D Technology|E-Commerce|E-Commerce Platforms|Fashion|IT Management|Mobile Commerce|Visualization',
#  '3D Technology|Electronics|Media',
#  '3D Technology|Energy|Natural Resources|Oil|Predictive Analytics',
#  '3D Technology|Games|Mobile|Social Games|Video Game Tournaments|Video Streaming|Virtual Worlds',
#  '3D Technology|Graphics',
#  '3D Technology|Health Care|Manufacturing',
#  '3D Technology|Human Computer Interaction|Interface Design|Web Browsers',
#  '3D Technology|Human Computer Interaction|Sensors',
#  '3D Technology|Maps|Navigation',
#  '3D Technology|Mass Customization|Retail',
#  '3D Technology|Mass Customization|Sales and Marketing',
#  '3D Technology|Portals|Web Hosting',
#  '3D Technology|Sensors',
#  '3D Technology|Software',
#  '3D|3D Printing',
#  '3D|3D Printing|3D Technology',
#  '3D|3D Printing|3D Technology|Augmented Reality|Consumer Electronics|Creative Industries|Displays|Games|Kinect|Television',
#  '3D|3D Printing|3D Technology|CAD|Enterprise Software|Industrial Automation|Software',
#  '3D|3D Printing|Application Platforms',
#  '3D|3D Printing|CAD|SaaS|Software|Web Development',
#  '3D|3D Printing|Consumers',
#  '3D|3D Printing|Content',
#  '3D|3D Printing|DIY|E-Commerce|Mass Customization|Personalization',
#  '3D|3D Printing|Graphic Design|Graphics|Printing|Software|Technology',
#  '3D|3D Printing|Internet|Manufacturing',
#  '3D|3D Printing|Manufacturing',
#  '3D|3D Printing|Printing',
#  '3D|3D Printing|Technology',
#  '3D|3D Technology|Android|Augmented Reality|Construction|Manufacturing|Virtual Worlds',
#  '3D|3D Technology|Application Platforms|Creative Industries',
#  '3D|3D Technology|Aquaculture',
#  '3D|3D Technology|Architecture|Cloud Data Services|ICT',
#  '3D|3D Technology|Augmented Reality|Marketplaces|Technology|Virtual Worlds',
#  '3D|3D Technology|Business Intelligence',
#  '3D|3D Technology|Design',
#  '3D|3D Technology|Digital Signage',
#  '3D|3D Technology|E-Commerce|Internet|Online Shopping',
#  '3D|3D Technology|Electronics|Product Design',
#  '3D|3D Technology|Entertainment|Game',
#  '3D|3D Technology|Events',
#  '3D|3D Technology|Hardware + Software',
#  '3D|3D Technology|Information Technology',
#  '3D|Advertising|Architecture|Augmented Reality|E-Commerce|Furniture|Interior Design|Online Shopping|Real Estate',
#  '3D|Advertising|Content|Content Creators|Content Delivery|Mobile',
#  '3D|Analytics|Geospatial',
#  '3D|Android|Apps|Games|iOS|Windows Phone 7',
#  '3D|App Marketing|Games|Gamification|Incentives|Loyalty Programs|Messaging|Mobile',
#  '3D|Apps|Games|Toys',
#  '3D|Apps|Image Recognition|Licensing|Software',
#  '3D|Apps|Online Gaming|PC Gaming',
#  '3D|Architecture|CAD|Construction|Manufacturing|Real Estate|SaaS|Software|Web Development',
#  '3D|Architecture|Commercial Real Estate|Property Management|Real Estate',
#  '3D|Architecture|Construction|Design|Engineering Firms',
#  '3D|Architecture|Design|Product Design|Software',
#  '3D|Architecture|Industrial|SaaS',
#  '3D|Architecture|Kinect|Real Estate|Smart Building|Software',
#  '3D|Artificial Intelligence',
#  '3D|Artificial Intelligence|Content|Image Recognition|iPad|iPhone|Machine Learning|Mobile|Robotics|Sensors|Software',
#  '3D|Art|CAD|Consulting|Design|Manufacturing|Printing|Rapidly Expanding|Services',
#  '3D|Audio|E-Commerce|Fashion|Jewelry|Printing',
#  '3D|Audio|Messaging|Public Relations|Real Time|Telephony|Virtualization',
#  '3D|Augmented Reality|Delivery|Hardware + Software|Health Care|Mobile|Software|Visualization',
#  '3D|Augmented Reality|Internet|Online Shopping|Photography|Retail',
#  '3D|Augmented Reality|Mobile|Mobile Commerce',
#  '3D|Augmented Reality|Software',
#  '3D|B2B|Retail|Shopping',
#  '3D|Broadcasting|Video Streaming',
#  '3D|Business Services|Design|E-Commerce|Mass Customization|Personalization',
#  '3D|CAD|Computer Vision|Manufacturing|Software',
#  '3D|CAD|Hardware + Software',
#  '3D|CAD|Marketplaces|Software',
#  '3D|Casual Games|Games',
#  '3D|Chat|CRM|Entertainment|Services|Software|Virtual Workforces',
#  '3D|Cloud Computing|E-Commerce|Enterprise Software|Finance|Mass Customization|Photography|Printing',
#  '3D|Cloud Computing|Medical Devices|SaaS|Software',
#  '3D|Computer Vision|Kinect|Robotics|Software',
#  '3D|Consumer Electronics|DIY',
#  '3D|Consumer Electronics|Hardware + Software|Human Computer Interaction|Sensors',
#  '3D|Consumer Internet|Entertainment|Games|Internet|Social Games|Virtual Currency',
#  '3D|Content|Development Platforms|Games|Software',
#  '3D|Content|Games|Graphics|Virtual Worlds',
#  '3D|Curated Web|E-Commerce|Home & Garden',
#  '3D|Curated Web|Fashion',
#  '3D|Curated Web|Graphics|Presentations|Real Time',
#  '3D|Data Visualization|Presentations|Software',
#  '3D|Design|Marketplaces',
#  '3D|Design|Software|Technology',
#  '3D|Digital Media|Graphics|Printing',
#  '3D|Digital Signage|Navigation|Sensors',
#  '3D|E-Commerce|Internet|Video',
#  '3D|E-Commerce|SNS|Social Buying',
#  '3D|Electronics|Manufacturing',
#  '3D|Enterprise Software|Games',
#  '3D|Enterprises|Hardware|Real Estate|Software',
#  '3D|Entertainment|Fitness|Hardware + Software|Health and Wellness|Wearables',
#  '3D|Entertainment|Games|Messaging',
#  '3D|Entertainment|Games|Social Media|Virtual Currency',
#  '3D|Entertainment|Messaging',
#  '3D|Finance|FinTech|Software',
#  '3D|Games',
#  '3D|Games|Mobile',
#  '3D|Games|Mobile|Mobile Games',
#  '3D|Games|Motion Capture',
#  '3D|Games|Social Games|Software',
#  '3D|Games|Software',
#  '3D|Games|Startups|Virtual Worlds',
#  '3D|Games|iOS|iPad|iPhone|Kids|Toys',
#  '3D|Game|Internet|Software|Web Development',
#  '3D|Graphics|Software',
#  '3D|Hardware + Software',
#  '3D|Health Care Information Technology|Medical Devices',
#  '3D|Health Care|Health Care Information Technology|Software|Video Games|Virtual Worlds',
#  '3D|Health Care|Medical Devices',
#  '3D|Industrial|Mobile|Photography|Software|Visualization',
#  '3D|Information Technology|Virtualization',
#  '3D|Manufacturing|Semiconductors',
#  '3D|Maps|Photography',
#  '3D|Medical|Physicians',
#  '3D|Mobile',
#  '3D|Mobile Games|Sports',
#  '3D|Mobile|Photography|Video',
#  '3D|Mobile|SaaS|Ticketing|Visualization',
#  '3D|Mobile|Web Development',
#  '3D|New Technologies|Services',
#  '3D|Photo Sharing|Software',
#  '3D|Photography|Product Development Services|Video',
#  '3D|Rapidly Expanding',
#  '3D|Retail|SaaS',
#  '3D|Services',
#  '3D|Software|Technology',
#  'Accounting',
#  'Accounting|Advertising|App Marketing|Incentives|Mobile',
#  'Accounting|Advertising|Apps|Distribution|Mobile',
#  'Accounting|Advertising|CRM|E-Commerce|Email Marketing|Lead Generation|Media|Performance Marketing|Sales and Marketing',
#  'Accounting|Advertising|Direct Marketing|SEO',
#  'Accounting|Advertising|Lead Generation',
#  'Accounting|Advertising|Performance Marketing',
#  'Accounting|Advice|Finance|Software',
#  'Accounting|Analytics|Data Integration|Finance|Insurance|Investment Management|Risk Management|SaaS|Software',
#  'Accounting|Analytics|Energy Efficiency|Finance|Financial Services|FinTech|Sales and Marketing|Technology',
#  'Accounting|Analytics|Financial Services|Software',
#  'Accounting|Analytics|SaaS',
#  'Accounting|Android|Chat|CRM|Enterprise Software|Home & Garden|iPhone|Mobile|Sales and Marketing|Security|Software|Tablets',
#  'Accounting|Apps|Banking|Families|Finance|Legal|Parenting|Payments|SaaS|Web Tools',
#  'Accounting|Apps|Billing|Cloud Computing|Freelancers|Human Resources|Internet|Mobile|SaaS|Small and Medium Businesses|Software|Web Development',
#  'Accounting|B2B|Business Intelligence|Business Productivity|Consulting|CRM|Distribution|E-Commerce|Enterprise Software|Linux|Mac|Manufacturing|Open Source|Professional Services|Project Management|Small and Medium Businesses|Software|Supply Chain Management',
#  'Accounting|B2B|Education|Social Entrepreneurship',
#  'Accounting|B2B|Enterprise Software|Finance|Network Security',
#  'Accounting|B2B|Enterprise Software|SaaS',
#  'Accounting|BPO Services|Business Productivity|Business Services|Finance|Human Resources|Optimization|Professional Services|Project Management|Tracking',
#  'Accounting|Banking|Billing|Business Services|Collaboration|CRM|Finance|Personal Finance|SaaS|Software',
#  'Accounting|Banking|Payments',
#  'Accounting|Big Data Analytics|Data Visualization|Finance Technology|SaaS',
#  'Accounting|Billing|CRM|Enterprise Software|SaaS',
#  'Accounting|Billing|CRM|Freelancers|Small and Medium Businesses|Software',
#  'Accounting|Billing|Cloud Computing|Enterprise Software|Financial Services|SaaS',
#  'Accounting|Billing|Credit Cards|Payments|Software',
#  'Accounting|Billing|Digital Media|Finance|Software',
#  'Accounting|Billing|E-Commerce',
#  'Accounting|Billing|E-Commerce|Enterprise Software',
#  'Accounting|Billing|Enterprise Software|Finance|Internet|Software',
#  'Accounting|Billing|Enterprise Software|Software',
#  'Accounting|Billing|Finance|Payments|Small and Medium Businesses',
#  'Accounting|Bitcoin|Finance Technology',
#  'Accounting|Business Development|Finance|Software|Web Development',
#  'Accounting|Business Services|CRM|Curated Web|Small and Medium Businesses|Startups',
#  'Accounting|Business Services|Cloud Computing|Enterprise Software|Finance|Financial Services|iOS|Mobile|Online Travel|SaaS|Small and Medium Businesses|Travel',
#  'Accounting|Business Services|Consulting|Enterprise Software|Small and Medium Businesses',
#  'Accounting|Business Services|Financial Services',
#  'Accounting|Business Services|Human Resources|Legal|Small and Medium Businesses',
#  'Accounting|CRM|Enterprise Software|Information Services|Information Technology|Point of Sale|Sales and Marketing|Software|Startups',
#  'Accounting|CRM|Enterprise Software|Network Security|SaaS|Software',
#  'Accounting|CRM|PaaS|Software',
#  'Accounting|Classifieds|Internet|Real Estate|Realtors|Search',
#  'Accounting|Cloud Computing|CRM|Developer Tools|Development Platforms|Enterprise Resource Planning|Enterprise Software|SaaS|Software',
#  'Accounting|Cloud Computing|CRM|Enterprise Software|SaaS|Software',
#  'Accounting|Cloud Computing|Collaboration|CRM|Enterprises|Network Security|Project Management|SaaS|Software|Storage',
#  'Accounting|Cloud Computing|Enterprise Resource Planning|Software',
#  'Accounting|Cloud Computing|Enterprise Software|Finance|SaaS|Software',
#  'Accounting|Cloud Computing|Enterprise Software|SaaS',
#  'Accounting|Cloud Computing|Enterprises|Enterprise Software|Identity|Identity Management|SaaS|Security|Software',
#  'Accounting|Cloud Computing|Small and Medium Businesses',
#  'Accounting|Cloud Management|Financial Services',
#  'Accounting|Collectibles|Credit|Payments|SaaS|Small and Medium Businesses|Software',
#  'Accounting|Comparison Shopping|Credit Cards|E-Commerce|Financial Services|Payments|Startups',
#  'Accounting|Consulting',
#  'Accounting|Consulting|CRM|Marketing Automation|Project Management',
#  'Accounting|Consulting|Professional Services',
#  'Accounting|Creative|Music|Video',
#  'Accounting|Credit Cards|E-Commerce|Payments',
#  'Accounting|Credit Cards|Mobile|Mobile Payments',
#  'Accounting|Credit Cards|Payments|Software',
#  'Accounting|Credit|Financial Services',
#  'Accounting|Curated Web|Finance|Freelancers|Local Businesses|Taxis',
#  'Accounting|Customer Service|Outsourcing|Tech Field Support',
#  'Accounting|Databases|Hardware + Software|Networking|Security|Software',
#  'Accounting|Developer APIs|Payments|Software',
#  'Accounting|Digital Rights Management|Legal|Music Services|Transaction Processing',
#  'Accounting|E-Commerce|Finance|SaaS',
#  'Accounting|Enterprise Resource Planning|Enterprise Software|Finance Technology|Financial Services|FinTech|Mobile|Mobile Software Tools|SaaS',
#  'Accounting|Enterprise Resource Planning|Freelancers|Mobile Payments|Online Scheduling|Payments|Productivity Software|Software',
#  'Accounting|Enterprise Software',
#  'Accounting|Enterprise Software|Freelancers|Small and Medium Businesses',
#  'Accounting|Enterprise Software|Real Estate|Software',
#  'Accounting|Enterprise Software|SaaS|Small and Medium Businesses',
#  'Accounting|Enterprises|Finance|Network Security|SaaS|Small and Medium Businesses|Software',
#  'Accounting|Finance',
#  'Accounting|Finance Technology|Financial Services|FinTech',
#  'Accounting|Finance Technology|Financial Services|Mobile|Mobile Payments|Payments',
#  'Accounting|Finance Technology|Information Technology|Software',
#  'Accounting|Finance Technology|Personal Finance|Retirement',
#  'Accounting|Finance|FinTech|SaaS',
#  'Accounting|Finance|Financial Services',
#  'Accounting|Finance|Financial Services|FinTech',
#  'Accounting|Finance|Hospitality|Mobile|Nightclubs|Nightlife|Restaurants|SaaS',
#  'Accounting|Finance|Insurance|Taxis',
#  'Accounting|Finance|Legal|Marketplaces',
#  'Accounting|Finance|Network Security|SaaS|Software|Startups|Technology',
#  'Accounting|Finance|News|Software',
#  'Accounting|Financial Services',
#  'Accounting|Financial Services|FinTech|Human Resources|Software',
#  'Accounting|Franchises|SaaS|Software',
#  'Accounting|Human Resources|Risk Management',
#  'Accounting|IT and Cybersecurity|Software',
#  'Accounting|Legal|Licensing|Music|Publishing|Transaction Processing',
#  'Accounting|Marketing Automation',
#  'Accounting|Mobile',
#  'Accounting|Mobile Payments|Software|Virtualization',
#  'Accounting|Nonprofits|Software',
#  'Accounting|Productivity Software|SaaS',
#  'Accounting|SaaS|Software',
#  'Accounting|Security',
#  'Accounting|Services|Software',
#  'Accounting|Software',
#  'Active Lifestyle|Apps|Consumers|Content|Health and Wellness|Mobile',
#  'Active Lifestyle|Bicycles|Manufacturing',
#  'Active Lifestyle|Curated Web|E-Commerce|Entertainment|Internet|Local|Marketplaces|Mobile|Online Reservations|Peer-to-Peer|Software|Ticketing|Travel|Travel & Tourism|Video Streaming',
#  'Active Lifestyle|Cyber|Families|Internet|Social Media|Social Media Platforms',
#  'Active Lifestyle|E-Commerce|Fashion|Kids',
#  'Active Lifestyle|E-Commerce|Health and Wellness|Retail',
#  'Active Lifestyle|Fitness',
#  'Active Lifestyle|Fitness|Local|Mobile|Social Games|Sports',
#  'Active Lifestyle|Fitness|Location Based Services',
#  'Active Lifestyle|Fitness|Marketplaces|Search|Sports',
#  'Active Lifestyle|Fitness|Medical',
#  'Active Lifestyle|Fitness|Mobile Commerce',
#  'Active Lifestyle|Fitness|Nutrition',
#  'Active Lifestyle|Health and Wellness|Health Care|Marketplaces|Nutrition|Personal Health|Sports|Training',
#  'Active Lifestyle|Health and Wellness|Lifestyle',
#  'Active Lifestyle|Information Services|Private Social Networking|Proximity Internet',
#  'Active Lifestyle|Lifestyle|Social Commerce',
#  'Active Lifestyle|Lifestyle|Social Media|Social Media Marketing|Travel|Travel & Tourism',
#  'Active Lifestyle|Nightclubs|Nightlife',
#  'Active Lifestyle|Nutrition|Specialty Foods',
#  'Active Lifestyle|Online Travel|Travel & Tourism',
#  'Active Lifestyle|Professional Services|Sports',
#  'Active Lifestyle|Soccer|Sports',
#  'Active Lifestyle|Sports|Training',
#  'Ad Targeting|Advertising',
#  'Ad Targeting|Advertising Exchanges|Advertising Platforms|SaaS',
#  'Ad Targeting|Advertising Platforms|Analytics|Big Data|Big Data Analytics|Brand Marketing|Digital Media|Internet Marketing',
#  'Ad Targeting|Advertising Platforms|Analytics|Events|Marketing Automation|Sales Automation',
#  'Ad Targeting|Advertising Platforms|Analytics|Optimization|Social Media Advertising',
#  'Ad Targeting|Advertising Platforms|Android|Email Marketing|Mobile Advertising|Web Browsers',
#  'Ad Targeting|Advertising Platforms|Big Data Analytics|Broadcasting|Digital Signage|Media|SaaS',
#  'Ad Targeting|Advertising Platforms|Big Data|Digital Media|Mobile Advertising|Television',
#  'Ad Targeting|Advertising Platforms|Content',
#  'Ad Targeting|Advertising Platforms|Data Integration',
#  'Ad Targeting|Advertising Platforms|Mobile Advertising|Retail Technology',
#  'Ad Targeting|Advertising|Advertising Exchanges|Advertising Networks|Advertising Platforms|Internet Marketing',
#  'Ad Targeting|Advertising|Advertising Platforms',
#  'Ad Targeting|Advertising|Advertising Platforms|Big Data|Brand Marketing|Digital Media|Media|Mobile|Mobile Video|Technology',
#  'Ad Targeting|Advertising|Advertising Platforms|Curated Web|E-Commerce|Internet Technology|Marketing Automation|Real Time|Retail Technology',
#  'Ad Targeting|Advertising|Advertising Platforms|Databases|Digital Media|Marketplaces',
#  'Ad Targeting|Advertising|Advertising Platforms|Design|Digital Media|Marketing Automation|Mobile Advertising|SaaS|Web Design',
#  'Ad Targeting|Advertising|Advertising Platforms|Digital Media|Media|Video',
#  'Ad Targeting|Advertising|Advertising Platforms|Internet Marketing|Market Research|Mobile|Mobile Advertising',
#  'Ad Targeting|Advertising|Advertising Platforms|Internet TV|Technology|Video',
#  'Ad Targeting|Advertising|Advertising Platforms|Sales and Marketing',
#  'Ad Targeting|Advertising|Analytics|Big Data Analytics|E-Commerce|Personalization|Search',
#  'Ad Targeting|Advertising|Analytics|Big Data|Machine Learning|Mobile|Predictive Analytics|Real Time|Sales and Marketing',
#  'Ad Targeting|Advertising|Analytics|Media|Mobile Advertising',
#  'Ad Targeting|Advertising|App Marketing|Digital Media|Mobile Advertising',
#  'Ad Targeting|Advertising|Application Platforms',
#  'Ad Targeting|Advertising|Apps|Brand Marketing|Mobile|Publishing|Sales and Marketing|Services|Wireless',
#  'Ad Targeting|Advertising|Apps|Consumer Goods|Facebook Applications|Mobile|Networking|Sales and Marketing|SMS|Social Media|Web CMS',
#  'Ad Targeting|Advertising|Apps|Location Based Services|Social Media',
#  'Ad Targeting|Advertising|Augmented Reality|Data Visualization|Image Recognition|Mobile|Sales and Marketing|Software',
#  'Ad Targeting|Advertising|Automotive|Facebook Applications|Optimization|SaaS|Sales and Marketing|Social Media|Social Media Advertising',
#  'Ad Targeting|Advertising|Big Data',
#  'Ad Targeting|Advertising|Big Data Analytics|Data Mining|E-Commerce|Machine Learning|Personalization|Reviews and Recommendations',
#  'Ad Targeting|Advertising|Big Data Analytics|Data Visualization|Digital Media|Enterprise Software|Internet Marketing|Technology',
#  'Ad Targeting|Advertising|Big Data Analytics|Identity Management|Mobile Analytics|Online Identity',
#  'Ad Targeting|Advertising|Big Data|Brand Marketing|Digital Media|Internet Marketing|Mobile|Online Video Advertising|Social Media',
#  'Ad Targeting|Advertising|Big Data|Local Businesses|Mobile|Software',
#  'Ad Targeting|Advertising|Content|Interest Graph|Monetization|Optimization|Publishing|Sales and Marketing|Social Media|Weddings',
#  'Ad Targeting|Advertising|Coupons|Mobile|Sales and Marketing',
#  'Ad Targeting|Advertising|Customer Service|Retail|Shopping',
#  'Ad Targeting|Advertising|Digital Media|Mobile Advertising',
#  'Ad Targeting|Advertising|Email|Optimization',
#  'Ad Targeting|Advertising|Internet Marketing',
#  'Ad Targeting|Advertising|Lead Generation|Shopping',
#  'Ad Targeting|Advertising|Location Based Services|Mobile|Tablets|Television',
#  'Ad Targeting|Advertising|Marketing Automation|Mobile|Online Identity|Optimization|SaaS',
#  'Ad Targeting|Advertising|Mobile Advertising',
#  'Ad Targeting|Advertising|Mobile|Monetization|Software',
#  'Ad Targeting|Advertising|Promotional',
#  'Ad Targeting|Advertising|Real Time',
#  'Ad Targeting|Advertising|Sales and Marketing',
#  'Ad Targeting|Advertising|Sales and Marketing|Social Media|Technology',
#  'Ad Targeting|Advertising|Software',
#  'Ad Targeting|Advertising|Web Tools',
#  'Ad Targeting|Analytics',
#  'Ad Targeting|Analytics|Big Data|Digital Media|Internet Marketing|Market Research|Publishing|Social Media',
#  'Ad Targeting|Analytics|Big Data|E-Commerce|Email|Email Marketing|Personalization|Public Relations',
#  'Ad Targeting|Analytics|Developer APIs|Finance|Machine Learning|Optimization|Sales and Marketing|Software',
#  'Ad Targeting|Analytics|Location Based Services|Mobile',
#  'Ad Targeting|App Marketing|Apps|Big Data|Mobile|Technology',
#  'Ad Targeting|Apps|Mobile Commerce',
#  'Ad Targeting|Artificial Intelligence|Content Discovery|Machine Learning|Predictive Analytics|Publishing|Semantic Search|Social Media',
#  'Ad Targeting|Assisitive Technology|Career Management|Career Planning|Consulting|Content Delivery|Creative|Crowdsourcing|Employment|Human Resource Automation|Human Resources|Innovation Management|Marketing Automation|Networking|Predictive Analytics|Private Social Networking|Professional Networking|Recruiting|Sales and Marketing|Skill Assessment|Social Media Marketing|Staffing Firms|Startups',
#  'Ad Targeting|Big Data Analytics|Brand Marketing|Content|Messaging|Mobile|Music|Psychology',
#  'Ad Targeting|Big Data Analytics|Consumer Behavior|Data Mining|Electronic Health Records|Health and Insurance|Health and Wellness|Health Care Information Technology|Interest Graph|Natural Language Processing|Personal Health|Pharmaceuticals|Predictive Analytics|Public Relations|Reviews and Recommendations|Semantic Search|Social Media Advertising|Social Media Monitoring|Text Analytics',
#  'Ad Targeting|Big Data Analytics|Mobile Advertising',
#  'Ad Targeting|Big Data|Coupons|E-Commerce|Real Time|Software',
#  'Ad Targeting|Brand Marketing|Direct Marketing|Location Based Services|Mobile|Mobile Advertising|Mobile Analytics|Mobile Video',
#  'Ad Targeting|Bridging Online and Offline|Local Advertising|Local Search|Location Based Services|Marketing Automation|Mobile|Performance Marketing|Shopping|Small and Medium Businesses',
#  'Ad Targeting|Business Analytics|CRM|Loyalty Programs|Marketplaces|Retail Technology',
#  'Ad Targeting|CRM|Internet|News|Personalization|Privacy|Web Design',
#  'Ad Targeting|Classifieds|E-Commerce',
#  'Ad Targeting|E-Commerce|Fashion|Reviews and Recommendations|Supply Chain Management',
#  'Ad Targeting|Lead Generation|Messaging|Mobile Advertising|Performance Marketing|Real Time|SaaS|Sensors',
#  'Ad Targeting|Mobile|Retail|Retail Technology',
#  'Ad Targeting|Online Video Advertising|Social Media',
#  'Ad Targeting|Optimization|Personalization|Software',
#  'Ad Targeting|Personalization|Semantic Search|Video on Demand',
#  'Ad Targeting|Privacy|Security|Web Hosting',
#  'Adaptive Equipment|Construction|Landscaping',
#  'Adaptive Equipment|Manufacturing',
#  'Adaptive Equipment|Sports',
#  'Advanced Materials',
#  'Advanced Materials|Advertising|Aerospace|Automotive|Displays|Hardware + Software|Wearables',
#  'Advanced Materials|Aerospace|Clean Technology|Space Travel',
#  'Advanced Materials|Analytics|Big Data|Machine Learning|Material Science',
#  'Advanced Materials|Biotechnology|Genetic Testing|Hardware + Software|Life Sciences|Medical Devices|Nanotechnology|Specialty Chemicals|Specialty Foods',
#  'Advanced Materials|Chemicals|Manufacturing|Material Science|Solar',
#  'Advanced Materials|Clean Technology|Electric Vehicles|Recycling',
#  'Advanced Materials|Clean Technology|Material Science|Nanotechnology',
#  'Advanced Materials|Food Processing',
#  'Advanced Materials|Manufacturing|Medical',
#  'Advanced Materials|Manufacturing|Renewable Energies',
#  'Advanced Materials|Material Science',
#  'Advanced Materials|Medical Devices|Nanotechnology',
#  'Advanced Materials|Nanotechnology|Technology',
#  'Advanced Materials|Retail|Utilities',
#  'Advanced Materials|Specialty Chemicals|Water',
#  'Adventure Travel|Aerospace|Space Travel|Travel',
#  'Adventure Travel|All Students|Colleges|Education|Events|Mobile|Tourism|Travel',
#  'Adventure Travel|Apps|Game',
#  'Adventure Travel|Art|Blogging Platforms|Maps|Mobile|Restaurants|Travel & Tourism',
#  'Adventure Travel|Augmented Reality|Games|MMO Games|Mobile|Transportation',
#  'Adventure Travel|Bicycles|Online Reservations',
#  'Adventure Travel|Boating Industry|Collaborative Consumption|Online Travel|Sailing Community|Social Travel|Tourism|Travel|Travel & Tourism|Vacation Rentals',
#  'Adventure Travel|Boating Industry|Collaborative Consumption|Peer-to-Peer|Social Travel|Travel & Tourism',
#  'Adventure Travel|Bridging Online and Offline|Online Travel|SaaS',
#  'Adventure Travel|Collaborative Consumption|Transportation|Travel',
#  'Adventure Travel|Curated Web|Internet|iOS|Mobile|Outdoors',
#  'Adventure Travel|Curated Web|Marketplaces',
#  'Adventure Travel|Curated Web|Marketplaces|Online Scheduling',
#  'Adventure Travel|Curated Web|Online Reservations|Sports',
#  'Adventure Travel|Curated Web|Outdoors|Travel',
#  'Adventure Travel|Customer Service|Diving|Online Travel|Reviews and Recommendations|Sales and Marketing|Social Media|Surveys|Travel',
#  'Adventure Travel|Entertainment|Local|Software|Travel',
#  'Adventure Travel|Entertainment|Location Based Services|Online Reservations',
#  'Adventure Travel|Health and Wellness|Internet Marketing|Leisure|Mobile Commerce|Mobile Games|Travel',
#  'Adventure Travel|Hospitality|Marketplaces|Online Travel|Startups|Travel|Travel & Tourism',
#  'Adventure Travel|Internet Marketing|Reviews and Recommendations|Sports',
#  'Adventure Travel|Leisure|Online Reservations',
#  'Adventure Travel|Lifestyle|Social Media|Travel & Tourism',
#  'Adventure Travel|Mobile|Social Media|Travel',
#  'Adventure Travel|Online Reservations|Software|Tourism',
#  'Adventure Travel|Online Reservations|Travel',
#  'Adventure Travel|Online Travel',
#  'Adventure Travel|Services|Social Travel',
#  'Adventure Travel|Social Travel|Travel',
#  'Adventure Travel|Sports|Travel',
#  'Adventure Travel|Tourism',
#  'Adventure Travel|Tourism|Travel & Tourism',
#  'Adventure Travel|Travel',
#  'Advertising',
#  'Advertising Exchanges|Advertising Networks|Advertising Platforms|Digital Entertainment|Internet TV|Mobile Advertising',
#  'Advertising Exchanges|Advertising Networks|Advertising Platforms|Mobile Advertising',
#  'Advertising Exchanges|Advertising Platforms',
#  'Advertising Exchanges|Advertising Platforms|Brand Marketing|Marketing Automation|Marketplaces|Mobile Advertising|Mobile Software Tools',
#  'Advertising Exchanges|Advertising Platforms|Mobile|Mobile Advertising',
#  'Advertising Exchanges|Apps|Mobile|Mobile Advertising|Mobile Software Tools|Online Video Advertising|Video',
#  'Advertising Exchanges|Content|Content Syndication|Marketplaces|Publishing|Sales and Marketing|Social Media',
#  'Advertising Exchanges|Employment|Human Resources|Recruiting',
#  'Advertising Exchanges|Mobile|Mobile Advertising|Mobile Video',
#  'Advertising Exchanges|Video',
#  'Advertising Networks',
#  'Advertising Networks|Advertising Platforms|Artificial Intelligence|Big Data|Machine Learning|Mobile|Mobile Advertising|Mobile Games|Mobile Video',
#  'Advertising Networks|Advertising Platforms|Consumer Internet|Mobile Advertising|Wireless',
#  'Advertising Networks|Advertising Platforms|Direct Advertising|File Sharing|Local Advertising|Photo Sharing',
#  'Advertising Networks|Advertising Platforms|Internet Marketing|Marketplaces',
#  'Advertising Networks|Advertising Platforms|Mobile Advertising|Monetization',
#  'Advertising Networks|Advertising Platforms|Mobile Advertising|Online Video Advertising|Social Media Advertising',
#  'Advertising Networks|Apps',
#  'Advertising Networks|Apps|Content|Location Based Services|Media|Mobile|News|Publishing|Reviews and Recommendations|Video|Video Streaming',
#  'Advertising Networks|B2B|Business Services|Curated Web|Lead Generation|Reputation|Reviews and Recommendations|Sales and Marketing',
#  'Advertising Networks|B2B|E-Commerce|Internet|Law Enforcement|Legal|Outsourcing|Reviews and Recommendations',
#  'Advertising Networks|B2B|Enterprise Software|Internet|Lead Generation|Networking|Online Shopping|Sales and Marketing',
#  'Advertising Networks|CRM|Professional Networking|Social Media|Social Network Media',
#  'Advertising Networks|Communications Infrastructure|Promotional',
#  'Advertising Networks|Consumer Internet|Curated Web|E-Commerce|Marketplaces|Mobile|New Product Development|Product Development Services',
#  'Advertising Networks|Coupons|Curated Web|Local|Local Coupons|Local Search|Private Social Networking|Reviews and Recommendations|Search',
#  'Advertising Networks|Ediscovery|iPhone|Location Based Services|Mobile|Private Social Networking|Social Media',
#  'Advertising Networks|Facebook Applications|Mobile|Recruiting|Search|Social Media',
#  'Advertising Networks|Games|Music|Video',
#  'Advertising Networks|Internet Marketing|Media|Recruiting|Skill Assessment|Social Media|Software|Training',
#  'Advertising Networks|Internet Radio Market|Mobile|Personalization',
#  'Advertising Networks|Internet|Media',
#  'Advertising Networks|Mobile Video|Online Video Advertising|Video',
#  'Advertising Platforms',
#  'Advertising Platforms|All Students|Application Platforms|App Marketing|Augmented Reality|Brand Marketing|Development Platforms|E-Commerce Platforms|Environmental Innovation|Events|Internet of Things|Maps|Search Marketing|Social Games|Social Media|Social Media Marketing|Social Media Platforms|Social + Mobile + Local|Social Opinion Platform|Software',
#  'Advertising Platforms|Analytics',
#  'Advertising Platforms|Analytics|Big Data|Digital Media',
#  'Advertising Platforms|Analytics|Curated Web|Data Mining',
#  'Advertising Platforms|Analytics|Lead Generation|SaaS',
#  'Advertising Platforms|Analytics|Mobile Advertising|Social Media',
#  'Advertising Platforms|Analytics|Real Time|Synchronization|Television',
#  'Advertising Platforms|Apps|Brand Marketing|Mobile Games|Retail',
#  'Advertising Platforms|Apps|Consumer Internet|Entertainment Industry|Events|Location Based Services|Mobile|Promotional',
#  'Advertising Platforms|Apps|Games|Mobile|Mobile Advertising',
#  'Advertising Platforms|Apps|Internet',
#  'Advertising Platforms|Apps|Monetization',
#  'Advertising Platforms|Big Data Analytics|Consumer Behavior|Email Marketing',
#  'Advertising Platforms|Big Data|Brand Marketing|Broadcasting|Consumer Electronics|E-Commerce Platforms|Internet|Mobile|News|SaaS|Social Media|Social Television|Technology|Television|Young Adults',
#  'Advertising Platforms|Big Data|Crowdfunding|Curated Web|Digital Media|Mobile|Politics|Social Media',
#  'Advertising Platforms|Big Data|Mobile Advertising',
#  'Advertising Platforms|Big Data|Prediction Markets|Real Estate',
#  'Advertising Platforms|Big Data|Retail',
#  'Advertising Platforms|Brand Marketing|E-Commerce Platforms|PaaS|Retail Technology',
#  'Advertising Platforms|Brand Marketing|Information Technology|SaaS',
#  'Advertising Platforms|Chat|Social Network Media|Teenagers',
#  'Advertising Platforms|Cloud Data Services|Communications Infrastructure|Hospitality|Payments|Promotional|Transportation',
#  'Advertising Platforms|Comparison Shopping|E-Commerce Platforms|Performance Marketing|Search|Shopping',
#  'Advertising Platforms|Computer Vision|Online Video Advertising',
#  'Advertising Platforms|Content Creators|Digital Media|News',
#  'Advertising Platforms|Content Discovery|Curated Web|Optimization|Social Media Advertising|Social Media Marketing|Social Television|Television',
#  'Advertising Platforms|Content Discovery|E-Commerce|Semantic Search|Social Commerce',
#  'Advertising Platforms|Content|Video',
#  'Advertising Platforms|Curated Web|Data Integration|SaaS|Software',
#  'Advertising Platforms|Curated Web|Loyalty Programs',
#  'Advertising Platforms|Digital Media',
#  'Advertising Platforms|Digital Media|Digital Signage|Mobile|Mobile Advertising|Web Development',
#  'Advertising Platforms|Digital Media|Machine Learning',
#  'Advertising Platforms|Digital Media|News|Sports|Technology',
#  'Advertising Platforms|Digital Media|Personalization|Software|Video',
#  'Advertising Platforms|E-Commerce',
#  'Advertising Platforms|E-Commerce|Internet|Web Development',
#  'Advertising Platforms|E-Commerce|Web Design',
#  'Advertising Platforms|Electric Vehicles|Internet of Things|Real Estate',
#  'Advertising Platforms|Email',
#  'Advertising Platforms|Email|Identity Management|Internet TV|Mobile Software Tools|Portals|Software',
#  'Advertising Platforms|Entertainment|News',
#  'Advertising Platforms|Events',
#  'Advertising Platforms|Events|Internet Marketing|SaaS|Search',
#  'Advertising Platforms|File Sharing|General Public Worldwide|Public Transportation|Transportation',
#  'Advertising Platforms|Finance Technology|FinTech|Human Resources',
#  'Advertising Platforms|Financial Services|Services',
#  'Advertising Platforms|Groceries|Online Shopping|Recipes',
#  'Advertising Platforms|Marketing Automation|Payments|Social Commerce|Social Media Marketing',
#  'Advertising Platforms|Marketing Automation|SaaS|Social Media Marketing',
#  'Advertising Platforms|Media|Real Time',
#  'Advertising Platforms|Mobile Advertising',
#  'Advertising Platforms|Mobile Advertising|Mobile Enterprise',
#  'Advertising Platforms|Mobile Advertising|Mobile Games',
#  'Advertising Platforms|Mobile|Mobile Advertising',
#  'Advertising Platforms|Mobile|Mobile Advertising|Mobile Games',
#  'Advertising Platforms|Online Travel|Social Travel',
#  'Advertising Platforms|Performance Marketing|Tracking',
#  'Advertising Platforms|Promotional',
#  'Advertising Platforms|SaaS',
#  'Advertising Platforms|Social Media Management|Software',
#  'Advertising Platforms|Software',
#  'Advertising|Advertising Exchanges|Advertising Networks|Advertising Platforms|Media|Video',
#  'Advertising|Advertising Exchanges|Advertising Platforms|Algorithms|Mobile|Mobile Advertising|PaaS|SaaS',
#  'Advertising|Advertising Exchanges|Advertising Platforms|Mobile Advertising|PaaS|SaaS',
#  'Advertising|Advertising Networks',
#  'Advertising|Advertising Networks|Advertising Platforms|Local Advertising|Outdoor Advertising',
#  'Advertising|Advertising Networks|Advertising Platforms|Mobile Advertising|Online Video Advertising',
#  'Advertising|Advertising Networks|Advertising Platforms|Mobile Advertising|Performance Marketing|SaaS',
#  'Advertising|Advertising Networks|App Marketing|Mobile',
#  'Advertising|Advertising Networks|Brand Marketing|Messaging|Mobile|Social Media',
#  'Advertising|Advertising Networks|Email|Messaging|Monetization',
#  'Advertising|Advertising Networks|Finance',
#  'Advertising|Advertising Networks|Mobile',
#  'Advertising|Advertising Platforms',
#  'Advertising|Advertising Platforms|Analytics|Automotive',
#  'Advertising|Advertising Platforms|Analytics|Information Technology',
#  'Advertising|Advertising Platforms|Analytics|Mobile Advertising|Predictive Analytics|SaaS|Social Media Marketing',
#  'Advertising|Advertising Platforms|Android|Internet|iPhone|Market Research|Photo Sharing|Private Social Networking|Social Network Media|Software|Web Development',
#  'Advertising|Advertising Platforms|Android|Mobile Advertising',
#  'Advertising|Advertising Platforms|Auctions|Internet Marketing|Performance Marketing|Sales and Marketing',
#  'Advertising|Advertising Platforms|Automotive|Lead Generation|Mobile',
#  'Advertising|Advertising Platforms|B2B',
#  'Advertising|Advertising Platforms|Big Data|Content Delivery|Content Syndication|Developer APIs|Digital Media|Entertainment|Film|Internet Marketing|Publishing|Search|Television|Video|Web Development',
#  'Advertising|Advertising Platforms|Big Data|Indoor Positioning|Local Advertising|Location Based Services|Marketing Automation|Mobile Advertising|Mobile Analytics',
#  'Advertising|Advertising Platforms|Brand Marketing|Drones|Startups|Technology',
#  'Advertising|Advertising Platforms|Brand Marketing|Marketing Automation',
#  'Advertising|Advertising Platforms|Brand Marketing|Social Media',
#  'Advertising|Advertising Platforms|Broadcasting|Enterprise Software',
#  'Advertising|Advertising Platforms|CRM|Digital Media|Enterprise Software|SaaS',
#  'Advertising|Advertising Platforms|Colleges',
#  'Advertising|Advertising Platforms|Content Discovery|Internet|Social Media|Social Media Platforms|Social Network Media',
#  'Advertising|Advertising Platforms|Developer APIs|SaaS',
#  'Advertising|Advertising Platforms|Digital Media|E-Commerce|Marketing Automation|Media|Portals|Real Time',
#  'Advertising|Advertising Platforms|Digital Media|Marketplaces|Online Video Advertising|Television',
#  'Advertising|Advertising Platforms|Digital Media|Mobile Advertising',
#  'Advertising|Advertising Platforms|Displays',
#  'Advertising|Advertising Platforms|E-Commerce|Internet Marketing|Media|Mobile Advertising|Mobile Commerce|Online Travel|Retail|Software',
#  'Advertising|Advertising Platforms|Email|Email Newsletters',
#  'Advertising|Advertising Platforms|Enterprise Software|Internet Radio Market|Software|Television',
#  'Advertising|Advertising Platforms|Internet Marketing',
#  'Advertising|Advertising Platforms|Location Based Services|Mobile|Mobile Analytics',
#  'Advertising|Advertising Platforms|Media',
#  'Advertising|Advertising Platforms|Media|Mobile|Mobile Advertising|Social Media Advertising',
#  'Advertising|Advertising Platforms|Mobile',
#  'Advertising|Advertising Platforms|Mobile Advertising',
#  'Advertising|Advertising Platforms|Mobile|Mobile Advertising|Online Video Advertising|Technology',
#  'Advertising|Advertising Platforms|Monetization|Software',
#  'Advertising|Advertising Platforms|Online Video Advertising|Real Time|Technology',
#  'Advertising|Advertising Platforms|Online Video Advertising|Software',
#  'Advertising|Advertising Platforms|Optimization|Software',
#  'Advertising|Advertising Platforms|Retail Technology',
#  'Advertising|Advertising Platforms|Services',
#  'Advertising|Advertising Platforms|Technology',
#  'Advertising|Algorithms|Auctions|Optimization|Search Marketing|Semantic Search',
#  'Advertising|All Markets|Auto|Automotive|Legal|Real Estate|Sales and Marketing|Software|Technology',
#  'Advertising|All Markets|Developer APIs|PaaS|Sales and Marketing',
#  'Advertising|All Markets|English-Speaking|Games',
#  'Advertising|All Students|Colleges|Local|Universities',
#  'Advertising|Analytics',
#  'Advertising|Analytics|Android|Consumer Electronics|Gps|iPhone|Mobile|Startups',
#  'Advertising|Analytics|Android|Gamification|Incentives|iPhone|Loyalty Programs|Mobile|Social Media|Software',
#  'Advertising|Analytics|Android|iPhone|Media|Mobile',
#  'Advertising|Analytics|App Marketing|Big Data Analytics|Data Mining|Internet Marketing|Market Research|Mobile',
#  'Advertising|Analytics|App Marketing|Data Visualization|Mobile|Performance Marketing',
#  'Advertising|Analytics|Apps|Big Data|Mobile|Mobile Advertising',
#  'Advertising|Analytics|Apps|Brand Marketing|Cause Marketing|Charity|Games|Mobile|Networking|Social Media',
#  'Advertising|Analytics|Apps|Data Integration|iOS|Mobile|Mobile Analytics|Optimization|Software',
#  'Advertising|Analytics|Apps|Ediscovery|Mobile|Promotional',
#  'Advertising|Analytics|Auctions',
#  'Advertising|Analytics|Automotive|Big Data|Cloud Computing|CRM|Developer APIs|E-Commerce|Email|Enterprise Software|Internet|Media|Mobile|Sales and Marketing|SEO|Software|Startups|Technology',
#  'Advertising|Analytics|B2B|Big Data|Location Based Services|Mobile|NFC',
#  'Advertising|Analytics|B2B|Cloud Computing|CRM|Lead Generation|Marketing Automation|SaaS',
#  'Advertising|Analytics|B2B|Sales and Marketing',
#  'Advertising|Analytics|Big Data Analytics|Content|Content Discovery|Curated Web|Email Marketing|Internet Marketing|Mobile|Web Tools',
#  'Advertising|Analytics|Big Data Analytics|Media',
#  'Advertising|Analytics|Big Data|Business Intelligence|Enterprise Software|Fraud Detection|SaaS|Security',
#  'Advertising|Analytics|Big Data|Business Intelligence|Services',
#  'Advertising|Analytics|Big Data|Cloud Computing|Digital Media|Entertainment|Media|Real Time|SaaS|Social Media|Technology',
#  'Advertising|Analytics|Big Data|Communities|Sales and Marketing|Social Media',
#  'Advertising|Analytics|Big Data|Content|E-Commerce|Internet Marketing|Personalization|Sales and Marketing|Search|Web Tools',
#  'Advertising|Analytics|Big Data|Credit|Finance Technology|FinTech|Human Resources|Media|Psychology|Surveys',
#  'Advertising|Analytics|Big Data|Data Mining|E-Commerce|Internet|Publishing|Sales and Marketing',
#  'Advertising|Analytics|Big Data|Digital Media|Freemium|Network Security|SaaS|Subscription Businesses',
#  'Advertising|Analytics|Big Data|Enterprise Software|Information Technology|Mobile Analytics|Sales and Marketing',
#  'Advertising|Analytics|Big Data|File Sharing|Mobile Social|Social Media',
#  'Advertising|Analytics|Big Data|Location Based Services|Mobile|Retail|Wireless',
#  'Advertising|Analytics|Big Data|Mobile Games|Software|Video Games',
#  'Advertising|Analytics|Big Data|Predictive Analytics|SaaS|Social Media',
#  'Advertising|Analytics|Big Data|Publishing',
#  'Advertising|Analytics|Biometrics|Broadcasting|Business Intelligence|Business Services|Crowdsourcing|Market Research|Media|Wearables',
#  'Advertising|Analytics|Blogging Platforms|Brand Marketing|E-Commerce|Email Marketing|Internet Marketing|SMS|Social Media|Web Design|Web Development',
#  'Advertising|Analytics|Blogging Platforms|Enterprise Software|Facebook Applications|Social CRM|Social Media|Social Media Management|Social Media Marketing|Twitter Applications',
#  'Advertising|Analytics|Brand Marketing|Consumer Electronics|Facebook Applications|Social Television|Television|Twitter Applications',
#  'Advertising|Analytics|Brand Marketing|Content|Digital Media',
#  'Advertising|Analytics|Brand Marketing|Content|Reviews and Recommendations',
#  'Advertising|Analytics|Brand Marketing|Internet|Search',
#  'Advertising|Analytics|Brand Marketing|Mobile|Sales and Marketing|Technology|Test and Measurement|Video',
#  'Advertising|Analytics|Brand Marketing|Publishing|Social Commerce|Social CRM|Social Media Management|Social Media Monitoring',
#  'Advertising|Analytics|Brand Marketing|Web Development',
#  'Advertising|Analytics|Business Intelligence|Business Services|Curated Web|Market Research|Software',
#  'Advertising|Analytics|Business Intelligence|Enterprise Software',
#  'Advertising|Analytics|Business Intelligence|Market Research',
#  'Advertising|Analytics|Business Services|E-Commerce|Education|Internet Marketing|Small and Medium Businesses',
#  'Advertising|Analytics|CRM|Email|Mobile|Productivity Software',
#  'Advertising|Analytics|Celebrity|Social Media',
#  'Advertising|Analytics|Concerts|Events|Music|Ticketing',
#  'Advertising|Analytics|Consumers|Mobile|Music|Sales and Marketing|Surveys|Telecommunications|Television',
#  'Advertising|Analytics|Content Syndication|Internet|Online Video Advertising|Software|Video',
#  'Advertising|Analytics|Content|CRM|Mobile|Mobile Video|Publishing|SaaS|SMS|Web Development',
#  'Advertising|Analytics|Content|Curated Web|Monetization|Optimization|Publishing|Reviews and Recommendations|Service Providers|Software|Video',
#  'Advertising|Analytics|Content|Social Media',
#  'Advertising|Analytics|Coupons|Groceries|Sales and Marketing',
#  'Advertising|Analytics|Curated Web|Design|Graphics|Market Research|Web Development',
#  'Advertising|Analytics|Curated Web|Publishing',
#  'Advertising|Analytics|Curated Web|SEO',
#  'Advertising|Analytics|Curated Web|Social Media|Web Design|Web Development',
#  'Advertising|Analytics|Customer Service|Direct Marketing|E-Commerce|Email Marketing|Marketing Automation|Sales and Marketing',
#  'Advertising|Analytics|Customer Service|SaaS',
#  'Advertising|Analytics|Digital Media|Internet Marketing|SaaS|Social Media Marketing|Software',
#  'Advertising|Analytics|Digital Media|Media|Mobile|Mobile Analytics|Predictive Analytics|Publishing',
#  'Advertising|Analytics|Direct Marketing|Facebook Applications|Internet Marketing|Social Commerce|Social Media Marketing|Twitter Applications',
#  'Advertising|Analytics|Direct Marketing|Internet Marketing|Social Commerce|Social Media|Video',
#  'Advertising|Analytics|Direct Marketing|Internet Marketing|Social Media|Test and Measurement',
#  'Advertising|Analytics|Displays|Mobile',
#  'Advertising|Analytics|Displays|Software',
#  'Advertising|Analytics|E-Commerce|Fashion|Lifestyle|Mobile|Shopping',
#  'Advertising|Analytics|E-Commerce|Optimization',
#  'Advertising|Analytics|E-Commerce|Optimization|Testing',
#  'Advertising|Analytics|E-Commerce|Retail',
#  'Advertising|Analytics|Entertainment|Film Distribution|Monetization|Video',
#  'Advertising|Analytics|Entertainment|Social Television',
#  'Advertising|Analytics|Facebook Applications|Media|Mobile|SaaS|Sales and Marketing|Social Media|Social Media Marketing|Technology|Twitter Applications',
#  'Advertising|Analytics|Finance|SEO',
#  'Advertising|Analytics|Finance|Sales and Marketing',
#  'Advertising|Analytics|Games|Networking|Social Media|Virtual Currency',
#  'Advertising|Analytics|Google Apps|Internet Marketing|Optimization|Search Marketing|SEO',
# ...
#  'Advertising|Apps|Brand Marketing|Facebook Applications|Marketing Automation|Mobile|SaaS|Sales and Marketing|Social CRM|Social Media|Social Media Advertising|Social Media Marketing|Social Media Platforms|Software',
#  'Advertising|Apps|Brand Marketing|Games|Mobile|Mobile Advertising|Sales and Marketing|Social Media|Tablets',
#  'Advertising|Apps|Brand Marketing|Loyalty Programs',
#  'Advertising|Apps|Brand Marketing|Mobile|Social Media Marketing',
#  'Advertising|Apps|Collaboration|Creative|Design|Fashion|Freelancers|Real Time|SaaS|Sales and Marketing|Services',
#  'Advertising|Apps|Consumer Electronics|Mobile|Retail|Sales and Marketing|Television',
#  'Advertising|Apps|Content Discovery|Facebook Applications|Mobile|Mobile Games|Sales and Marketing|Social Media|Twitter Applications|Video',
#  'Advertising|Apps|Contests|Facebook Applications|Gambling|Gamification|Internet|Mobile|Photography|Polling|Promotional|Weddings',
#  'Advertising|Apps|Coupons|Direct Marketing|Facebook Applications|Incentives|QR Codes|SEO|Social Media Advertising',
#  'Advertising|Apps|Curated Web|E-Commerce|iPhone|Local|Mobile',
#  'Advertising|Apps|Curated Web|Internet|Local Search|Location Based Services',
#  'Advertising|Apps|Customer Service|E-Commerce|Software|User Experience Design|Web Development',
#  'Advertising|Apps|Data Integration|Mobile|Mobile Advertising|Software',
#  'Advertising|Apps|Digital Media|EdTech|Educational Games|Games|Mobile',
#  'Advertising|Apps|Discounts|Incentives|Mobile',
#  'Advertising|Apps|Distribution|Publishing|SaaS',
#  'Advertising|Apps|Education|iOS|iPad|Media|News|Publishing|Software|Tablets|Web Development',
#  'Advertising|Apps|Entertainment|Mobile',
#  'Advertising|Apps|Events|Guides|Internet|Local|Local Based Services|Mobile|Restaurants|SaaS|Subscription Businesses|Web CMS',
#  'Advertising|Apps|Facebook Applications|Location Based Services|Photo Sharing|Sales and Marketing|Social Media|Twitter Applications',
#  'Advertising|Apps|Facebook Applications|SaaS|Sales and Marketing|Social Media|Social Media Marketing|Software',
#  'Advertising|Apps|Games|Mobile|Wireless',
#  'Advertising|Apps|Gamification|Incentives|Mobile|Mobile Games|Social Games|Social Media|User Experience Design',
#  'Advertising|Apps|Hardware|Internet of Things|Location Based Services|Mobile|Mobile Shopping|Proximity Internet|Retail|Shopping',
#  'Advertising|Apps|Local|Loyalty Programs',
#  'Advertising|Apps|Local|Mobile|Search|Technology|Wireless',
#  'Advertising|Apps|Media|Mobile|Mobile Advertising|Mobile Analytics|Social + Mobile + Local|Software',
#  'Advertising|Apps|Mobile Commerce',
#  'Advertising|Apps|Mobile|Sales and Marketing',
#  'Advertising|Apps|Publishing',
#  'Advertising|Apps|Sales and Marketing|Technology',
#  'Advertising|Apps|Software|Web Hosting',
#  'Advertising|Architecture|Boating Industry|Consumer Electronics|Digital Signage|Displays|Hardware|Home Decor|Hospitality|Internet of Things|Retail Technology',
#  'Advertising|Architecture|Brand Marketing|Design|Presentations|Sales and Marketing',
#  'Advertising|Artificial Intelligence|Auctions|Big Data|Media',
#  'Advertising|Artificial Intelligence|Brand Marketing|E-Commerce|Internet|Internet of Things|Mobile|Mobile Commerce|Mobile Shopping|Online Shopping|Retail|Retail Technology|Search|Semantic Search|Shopping',
#  'Advertising|Artificial Intelligence|Business Intelligence|Internet Marketing|Social Media Marketing',
#  'Advertising|Artificial Intelligence|Curated Web|Discounts|E-Commerce|Incentives|Loyalty Programs|Natural Language Processing|Social Commerce',
#  'Advertising|Artists Globally|Creative|Design|EdTech|Education|Employment|Finance|FinTech|Networking|Search|Social Media|Social Network Media|Stock Exchanges',
#  'Advertising|Art|Audio|Blogging Platforms|Business Development|Chat|Entertainment|Events|Finance|Forums|Franchises|Human Resources|Legal|News|Photography|Social Media|Video',
#  'Advertising|Art|Business Services|Publishing|Real Estate',
#  'Advertising|Art|Internet|Networking|Startups',
#  'Advertising|Assisitive Technology|Consulting|Entrepreneur',
#  'Advertising|Auctions',
#  'Advertising|Auctions|Business Services|Cars|Classifieds|Computers|Discounts|E-Commerce|Home & Garden|Local|Marketplaces|Property Management|Wholesale',
#  'Advertising|Auctions|Creative',
#  'Advertising|Auctions|Digital Media',
#  'Advertising|Auctions|Discounts|E-Commerce|Shopping|Video',
#  'Advertising|Auctions|E-Commerce|Internet Marketing|Lead Generation',
#  'Advertising|Auctions|Internet',
#  'Advertising|Auctions|Internet Marketing|Mobile|Performance Marketing',
#  'Advertising|Auctions|Mobile',
#  'Advertising|Auctions|Mobile|Tablets',
#  'Advertising|Auctions|Mobile|Tablets|Video',
#  'Advertising|Auctions|Performance Marketing',
#  'Advertising|Auctions|Publishing',
#  'Advertising|Auctions|Search|Semantic Search|SEO',
#  'Advertising|Auctions|Television|Video',
#  'Advertising|Audio',
#  'Advertising|Audio|Audiobooks|Digital Media|E-Commerce|Freelancers|Marketplaces|Media|Mobile|Video|Video Streaming',
#  'Advertising|Audio|Blogging Platforms|Cloud Data Services|E-Commerce|Facebook Applications|Mobile|Networking|Photography|Social Network Media|Video|Video Streaming',
#  'Advertising|Audio|Broadcasting|Content|Events|Finance|FinTech|Local|Media|SaaS|Software|Web CMS',
#  'Advertising|Audio|Content Syndication|Digital Rights Management|Enterprise Software|Image Recognition|SaaS|Video|Video Streaming',
#  'Advertising|Audio|Content|Digital Media|Media|Monetization|Video',
#  'Advertising|Audio|Curated Web|Messaging|Telephony',
#  'Advertising|Audio|Email Marketing|Events|Internet|Semantic Web|Video Conferencing',
#  'Advertising|Augmented Reality',
#  'Advertising|Augmented Reality|Brand Marketing',
#  'Advertising|Augmented Reality|Computer Vision|Education|Image Recognition|Mobile|Wearables',
#  'Advertising|Augmented Reality|Creative|Games|Internet|Mobile|Property Management|Retail|Sales and Marketing',
#  'Advertising|Augmented Reality|Curated Web|Mobile|Mobile Commerce|Social Media|Social Media Marketing|Visual Search',
#  'Advertising|Augmented Reality|Games|Mobile|Video Games|Virtual Goods|Virtual Worlds',
#  'Advertising|Augmented Reality|K-12 Education|Mobile',
#  'Advertising|Automotive',
#  'Advertising|Automotive|CRM|Email Marketing|Internet Marketing|Lead Generation',
#  'Advertising|Automotive|Classifieds|Marketplaces|Online Rental',
#  'Advertising|Automotive|Consumer Internet|Retail|Search|SEO',
#  'Advertising|Automotive|Creative|E-Commerce|Enterprise Software|Internet|Sales and Marketing|SEO|Services|Social Media',
#  'Advertising|Automotive|Internet|Internet Marketing|Local|Sales and Marketing|Small and Medium Businesses',
#  'Advertising|Automotive|Sales and Marketing|Social Media',
#  'Advertising|B2B|Brand Marketing|Digital Media|Digital Rights Management|E-Commerce|Mobile Commerce|Sales and Marketing|Social Commerce|Social Media',
#  'Advertising|B2B|Consulting|E-Commerce|Web Development',
#  'Advertising|B2B|Consumer Internet|Internet|Marketplaces',
#  'Advertising|B2B|Digital Media|SaaS|Social Media|Social Media Marketing|Software',
#  'Advertising|B2B|E-Commerce',
#  'Advertising|B2B|Enterprises|Marketing Automation|SaaS|Software',
#  'Advertising|B2B|Events|Lead Generation|Media|SaaS|Software',
#  'Advertising|B2B|Groceries',
#  'Advertising|B2B|Health and Wellness|Sales and Marketing',
#  'Advertising|B2B|Local|Sales and Marketing|Social Media|Sponsorship',
#  'Advertising|B2B|Marketing Automation',
#  'Advertising|B2B|Marketplaces|Procurement|Small and Medium Businesses',
#  'Advertising|B2B|Promotional|Small and Medium Businesses|Social Media Management',
#  'Advertising|B2B|SaaS|Sales and Marketing|Software',
#  'Advertising|Babies|Classifieds|Curated Web|Digital Media|Kids|Parenting|Social Network Media',
#  'Advertising|Banking|Credit Cards|Discounts|Incentives|Shopping',
#  'Advertising|Beauty|Brand Marketing|Content|Digital Media|Fashion|Lifestyle',
#  'Advertising|Beauty|Business Services|Consumer Goods|Health Care|Internet|Personal Health|Sales and Marketing',
#  'Advertising|Big Data',
#  'Advertising|Big Data Analytics|Brand Marketing|E-Commerce|Lead Generation',
#  'Advertising|Big Data Analytics|Consumer Behavior',
#  'Advertising|Big Data Analytics|Consumers|CRM|Gamification|Incentives|Loyalty Programs|Media',
#  'Advertising|Big Data Analytics|Curated Web|Digital Signage|Market Research|Media|Sales and Marketing',
#  'Advertising|Big Data Analytics|Delivery|Groceries|Recipes',
#  'Advertising|Big Data Analytics|Digital Media|Internet',
#  'Advertising|Big Data Analytics|E-Commerce',
#  'Advertising|Big Data Analytics|E-Commerce|Technology',
#  'Advertising|Big Data Analytics|Psychology',
#  'Advertising|Big Data Analytics|Search|Semantic Search|Software',
#  'Advertising|Big Data|Big Data Analytics|Call Center Automation|Facebook Applications|Internet Marketing|Mobile|Predictive Analytics|SaaS|Search Marketing|Semantic Search|Social Media Marketing',
#  'Advertising|Big Data|Big Data Analytics|FinTech|Games|Incubators|Internet|Mobile|Mobile Games|Startups',
#  'Advertising|Big Data|Brand Marketing|CRM|Data Integration|Email Marketing|Internet Marketing|Mobile|SaaS|Social Media Marketing|Technology',
#  'Advertising|Big Data|Business Intelligence|Content|Portals|Publishing|SaaS|Software',
#  'Advertising|Big Data|Cloud Computing|Facebook Applications|Hospitality|Hotels|Internet of Things|Loyalty Programs|Mobile|Promotional|Restaurants|Retail|Social Media|Transportation',
#  'Advertising|Big Data|Communities|Consumer Lending|Content|Curated Web|Digital Media|EdTech|Education|Financial Services|Generation Y-Z|Guides|K-12 Education|Lead Generation|Marketplaces|Reviews and Recommendations|Startups|Universities|Young Adults',
#  'Advertising|Big Data|Consumer Goods|Facebook Applications|Social Media',
#  'Advertising|Big Data|Curated Web|Privacy',
#  'Advertising|Big Data|Data Centers',
#  'Advertising|Big Data|E-Commerce',
#  'Advertising|Big Data|Email',
#  'Advertising|Big Data|Events',
#  'Advertising|Big Data|Games|Predictive Analytics|Television|Video',
#  'Advertising|Big Data|Home Automation|Security',
#  'Advertising|Big Data|Information Technology|Mobile',
#  'Advertising|Big Data|Internet Marketing',
#  'Advertising|Big Data|Marketing Automation|Predictive Analytics|Real Estate|SaaS',
#  'Advertising|Big Data|Media|Online Video Advertising|Social Media|Social Media Marketing|Technology|Video',
#  'Advertising|Big Data|Mobile',
#  'Advertising|Big Data|Mobile Commerce|Travel',
#  'Advertising|Big Data|Mobile Shopping|Online Shopping|Shopping',
#  'Advertising|Big Data|SaaS|Sales and Marketing',
#  'Advertising|Big Data|SaaS|Software',
#  'Advertising|Big Data|Software',
#  'Advertising|Blogging Platforms|Browser Extensions|Information Services|Information Technology|Internet|Semantic Web|Software|Web Browsers',
#  'Advertising|Blogging Platforms|Business Analytics|Forums|Security|Web Tools',
#  'Advertising|Blogging Platforms|Chat|Classifieds|Marketplaces|Music|Social Games|Social Network Media|Video',
#  'Advertising|Blogging Platforms|Curated Web|Publishing',
#  'Advertising|Blogging Platforms|Facebook Applications|Sales and Marketing|Social Media|Twitter Applications',
#  'Advertising|Blogging Platforms|Facebook Applications|Social Media|Twitter Applications',
#  'Advertising|Blogging Platforms|Identity|Social Media',
#  'Advertising|Blogging Platforms|Internet|Internet Marketing|Sales and Marketing|Social Media',
#  'Advertising|Blogging Platforms|Media|Social Media',
#  'Advertising|Blogging Platforms|Sales and Marketing',
#  'Advertising|Blogging Platforms|Search|SEO',
#  'Advertising|Brand Marketing',
#  'Advertising|Brand Marketing|Business Analytics|Internet Marketing|Marketing Automation|Market Research|Politics|Predictive Analytics',
#  'Advertising|Brand Marketing|Business Services|Coffee|Creative|Sales and Marketing|Startups',
#  'Advertising|Brand Marketing|Celebrity|Public Relations|Sales and Marketing|Social Media',
#  'Advertising|Brand Marketing|Celebrity|Reviews and Recommendations|Social Network Media',
#  'Advertising|Brand Marketing|Clinical Trials|Consumers|Fitness|Health and Wellness|Health Care|Life Sciences|Market Research',
#  'Advertising|Brand Marketing|Consumer Behavior|Promotional',
#  'Advertising|Brand Marketing|Consumers|Sales and Marketing',
#  'Advertising|Brand Marketing|Content',
#  'Advertising|Brand Marketing|Content|Content Creators|Creative|Crowdsourcing|Design|Marketplaces|Market Research|SaaS|Sales and Marketing|Social Media|Social Media Marketing',
#  'Advertising|Brand Marketing|Content|Creative|Curated Web|Photography|Project Management|Social Network Media|Video',
#  'Advertising|Brand Marketing|Content|Digital Media|Email Newsletters|Social Media',
#  'Advertising|Brand Marketing|Curated Web|Public Relations|Sales and Marketing|Social Media|Social Media Monitoring',
#  'Advertising|Brand Marketing|Customer Service|Entrepreneur|Game Mechanics|Gamification',
#  'Advertising|Brand Marketing|Data Integration',
#  'Advertising|Brand Marketing|Design|Web Design|Web Development',
#  'Advertising|Brand Marketing|Digital Media|E-Commerce|Internet Marketing|Public Relations|Social Media|Web Development',
#  'Advertising|Brand Marketing|Digital Media|Licensing|Music',
#  'Advertising|Brand Marketing|Digital Media|Mobile|Startups|Technology',
#  'Advertising|Brand Marketing|Direct Marketing|Internet|Media|Mobile|Social Media',
#  'Advertising|Brand Marketing|Discounts|Entertainment|Media|Music|Sponsorship',
#  'Advertising|Brand Marketing|Distribution|Facebook Applications|Media|Mobile|Video|Video Streaming',
#  'Advertising|Brand Marketing|E-Commerce|Mobile|Mobile Advertising',
#  'Advertising|Brand Marketing|E-Commerce|Sporting Goods',
#  'Advertising|Brand Marketing|Enterprise Software|SaaS',
#  'Advertising|Brand Marketing|Entertainment|Sales and Marketing',
#  'Advertising|Brand Marketing|Finance|Lead Generation|Sales and Marketing',
#  'Advertising|Brand Marketing|Franchises|Internet|Startups',
#  'Advertising|Brand Marketing|Internet Marketing|Payments|Social Innovation|Social Media',
#  'Advertising|Brand Marketing|Internet Marketing|Social Media|Social Media Management|Social Media Marketing',
#  'Advertising|Brand Marketing|Lead Generation',
#  'Advertising|Brand Marketing|Lead Generation|Predictive Analytics|Social Media Marketing|Surveys',
#  'Advertising|Brand Marketing|Lead Generation|Sales and Marketing|Sports',
#  'Advertising|Brand Marketing|Local Search|Real Time',
#  'Advertising|Brand Marketing|Loyalty Programs|Sales and Marketing',
#  'Advertising|Brand Marketing|Marketing Automation|SEO|Video',
#  'Advertising|Brand Marketing|Marketing Automation|Social Media|Social Media Advertising|Social Media Marketing',
#  'Advertising|Brand Marketing|Marketplaces|Startups',
#  'Advertising|Brand Marketing|Media|Mobile Advertising',
#  'Advertising|Brand Marketing|Media|Music|Personalization|Sales and Marketing',
#  'Advertising|Brand Marketing|Mobile',
#  'Advertising|Brand Marketing|Neuroscience|Sales and Marketing|Twitter Applications',
#  'Advertising|Brand Marketing|Optimization',
#  'Advertising|Brand Marketing|Service Providers',
#  'Advertising|Brand Marketing|Technology',
#  'Advertising|Brand Marketing|Video',
#  'Advertising|Bridging Online and Offline|Classifieds|Curated Web|Local Services|Marketplaces|Mobile|Service Providers',
#  'Advertising|Bridging Online and Offline|Mobile Advertising',
#  'Advertising|Broadcasting|Drones|Film|Film Production|Marketplaces|Media|News|Promotional|Surveys|Tourism|TV Production',
#  'Advertising|Business Analytics|Mobile Commerce',
#  'Advertising|Business Development',
#  'Advertising|Business Development|Content|New Product Development|Project Management|Sales and Marketing|SEO|Small and Medium Businesses|Social Media|Software|User Experience Design|Web Development',
#  'Advertising|Business Development|Digital Media|Entrepreneur|Local Businesses|Local Services|Social Entrepreneurship|Startups',
#  'Advertising|Business Intelligence',
#  'Advertising|Business Intelligence|CRM|Google Glass|Lead Generation|Location Based Services|Networking|Professional Networking|Social Media',
#  'Advertising|Business Intelligence|E-Commerce|Market Research|Media|Mobile|Social Media',
#  ...]

# %% [markdown]
# __Имеем 22 105 уникальных категорий в трейн и 6 206 в тест__

# %% [markdown]
# __Приведем поле category_list к списку__

# %%
train['category_list'] = train['category_list'].str.split('|')

# %%
train.head()
# Out:
#                      name                              category_list  \
# 0               Lunchgate         [Online Reservations, Restaurants]
# 1                 EarLens  [Manufacturing, Medical, Medical Devices]
# 2  Reviva Pharmaceuticals                            [Biotechnology]
# 3    Sancilio and Company                              [Health Care]
# 4     WireTough Cylinders                            [Manufacturing]
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds founded_at first_funding_at last_funding_at  \
# 0        Zürich               2 2009-10-17       2011-05-01      2014-12-01
# 1  Redwood City               4 2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3 2006-01-01       2012-08-20      2014-07-02
# 3           NaN               3 2004-01-01       2011-09-01      2014-07-18
# 4       Bristol               1 2010-05-12       2012-02-01      2012-02-01
#
#   closed_at
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT

# %% [markdown]
# __Приведем элементы списка категорий к нижнему регистру и избавимся от возможных пробелов__

# %%
train['category_list'] = train['category_list'].apply(lambda x: [category.strip().lower() for category in x] if isinstance(x, list) else x)

# %%
train['category_list'] = train['category_list'].apply(lambda x: x if isinstance(x, list) else [])

# %%
train.head()
# Out:
#                      name                              category_list  \
# 0               Lunchgate         [online reservations, restaurants]
# 1                 EarLens  [manufacturing, medical, medical devices]
# 2  Reviva Pharmaceuticals                            [biotechnology]
# 3    Sancilio and Company                              [health care]
# 4     WireTough Cylinders                            [manufacturing]
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds founded_at first_funding_at last_funding_at  \
# 0        Zürich               2 2009-10-17       2011-05-01      2014-12-01
# 1  Redwood City               4 2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3 2006-01-01       2012-08-20      2014-07-02
# 3           NaN               3 2004-01-01       2011-09-01      2014-07-18
# 4       Bristol               1 2010-05-12       2012-02-01      2012-02-01
#
#   closed_at
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT

# %%
flattened_categories = [category for sublist in train['category_list'] for category in sublist]
unique_categories = list(set(flattened_categories))

# %%
len(unique_categories)
# Out:
# 854

# %% [markdown]
# - __Имеем 854 уникальных названий категорий__
# - __Попробуем использовать библиотеку fuzzy для объеденения категорий по схожести текста__

# %%
def find_similar_categories(category, all_categories, threshold=85):
    matches = process.extract(category, all_categories, limit=5)  
    return [match for match, score in matches if score >= threshold]  

similar_categories = {category: find_similar_categories(category, unique_categories) for category in unique_categories}

for category, matches in similar_categories.items():
    print(f"{category}: {matches}")
# Out:
# babies: ['babies']
# utilities: ['utilities']
# intelligent systems: ['intelligent systems', 'systems']
# tablets: ['tablets']
# boating industry: ['boating industry', 'health services industry', 'shipping broker industry']
# human computer interaction: ['human computer interaction', 'human resources', 'computer vision']
# retail: ['retail', 'retail technology', 'custom retail', 'specialty retail']
# physical security: ['physical security', 'security']
# ios: ['ios', 'automated kiosk']
# deep information technology: ['deep information technology', 'information technology', 'technology', 'retail technology', 'finance technology']
# cyber: ['cyber', 'cyber security', 'it and cybersecurity']
# baby boomers: ['baby boomers']
# reading apps: ['reading apps', 'apps']
# all markets: ['all markets', 'prediction markets']
# content syndication: ['content syndication', 'content']
# bioinformatics: ['bioinformatics']
# nanotechnology: ['nanotechnology']
# shared services: ['shared services', 'services', 'postal and courier services', 'product development services', 'location based services']
# governance: ['governance']
# human resources: ['human resources', 'human computer interaction', 'human resource automation']
# retail technology: ['retail technology', 'retail', 'technology', 'deep information technology', 'health care information technology']
# green: ['green', 'green consumer goods', 'greentech', 'green building']
# cloud gaming: ['cloud gaming', 'cloud data services', 'cloud infrastructure']
# quantified self: ['quantified self']
# business analytics: ['business analytics', 'analytics', 'business information systems']
# communities: ['communities']
# internet of things: ['internet of things', 'internet', 'internet tv']
# incentives: ['incentives']
# mobile security: ['mobile security', 'security', 'mobile', 'social + mobile + local', 'mobile emergency&health']
# enterprise software: ['enterprise software', 'software', 'embedded hardware and software']
# simulation: ['simulation']
# user experience design: ['user experience design', 'experience design', 'design', 'product design', 'user interface']
# art: ['art', 'artificial intelligence', 'charter schools', 'artists globally', 'smart building']
# physicians: ['physicians']
# clean energy: ['clean energy', 'energy', 'clean technology it', 'industrial energy efficiency']
# mobile social: ['mobile social', 'mobile', 'mobile software tools', 'mobile infrastructure', 'social media management']
# enterprise security: ['enterprise security', 'security']
# enterprise purchasing: ['enterprise purchasing', 'enterprise 2.0']
# architecture: ['architecture']
# group sms: ['group sms', 'sms']
# office space: ['office space']
# non profit: ['non profit', 'nonprofits']
# classifieds: ['classifieds']
# politics: ['politics']
# film: ['film', 'film distribution', 'film production']
# natural resources: ['natural resources', 'natural language processing']
# sales automation: ['sales automation', 'auto', 'human resource automation']
# interface design: ['interface design', 'design', 'web design']
# information security: ['information security', 'security', 'health care information technology', 'data security']
# lighting: ['lighting']
# resorts: ['resorts']
# freetoplay gaming: ['freetoplay gaming', 'pc gaming']
# nightlife: ['nightlife', 'guide to nightlife']
# entertainment: ['entertainment', 'in-flight entertainment', 'digital entertainment', 'entertainment industry']
# generation y-z: ['generation y-z', 'biomass power generation']
# communications hardware: ['communications hardware', 'hardware']
# nutraceutical: ['nutraceutical']
# hedge funds: ['hedge funds']
# motion capture: ['motion capture']
# consumer behavior: ['consumer behavior']
# web presence management: ['web presence management', 'web browsers', 'it management', 'task management', 'web cms']
# translation: ['translation']
# displays: ['displays']
# enterprise search: ['enterprise search', 'search', 'enterprise resource planning']
# usability: ['usability']
# neuroscience: ['neuroscience']
# direct advertising: ['direct advertising', 'advertising', 'direct sales']
# distributors: ['distributors']
# artificial intelligence: ['artificial intelligence', 'art']
# fintech: ['fintech']
# mobile search: ['mobile search', 'mobile', 'search', 'mobile software tools', 'mobile infrastructure']
# google glass: ['google glass']
# information services: ['information services', 'services', 'bpo services', 'health care information technology']
# telephony: ['telephony']
# mobile software tools: ['mobile software tools', 'mobile', 'software', 'mobile social', 'mobile search']
# career planning: ['career planning', 'enterprise resource planning']
# renewable tech: ['renewable tech', 'high tech', 'hi tech', 'non-tech']
# console gaming: ['console gaming', 'pc gaming']
# video game tournaments: ['video game tournaments', 'video', 'game', 'game mechanics', 'video chat']
# 3d printing: ['3d printing', 'printing', '3d']
# soccer: ['soccer']
# automotive: ['automotive', 'auto']
# games: ['games', 'social games', 'casual games', 'serious games', 'mmo games']
# cosmetics: ['cosmetics']
# microblogging: ['microblogging']
# life sciences: ['life sciences']
# east africa: ['east africa', 'west africa']
# content delivery: ['content delivery', 'content', 'delivery', 'content discovery']
# in-flight entertainment: ['in-flight entertainment', 'entertainment', 'made in italy']
# twin-tip skis: ['twin-tip skis']
# commodities: ['commodities']
# theatre: ['theatre']
# surfing community: ['surfing community']
# android: ['android']
# young adults: ['young adults']
# social bookmarking: ['social bookmarking', 'social games', 'social news', 'social media', 'social crm']
# retirement: ['retirement']
# defense: ['defense']
# oil: ['oil', 'oil & gas', 'oil and gas']
# public safety: ['public safety', 'public transportation', 'general public worldwide']
# industrial: ['industrial', 'industrial automation', 'industrial energy efficiency']
# sunglasses: ['sunglasses']
# advertising: ['advertising', 'direct advertising', 'online video advertising', 'social media advertising', 'advertising platforms']
# email marketing: ['email marketing', 'email']
# freelancers: ['freelancers']
# content: ['content', 'content syndication', 'content delivery', 'content discovery', 'content creators']
# social games: ['social games', 'games', 'game', 'social bookmarking', 'social media management']
# crowdfunding: ['crowdfunding']
# finance technology: ['finance technology', 'technology', 'finance', 'deep information technology', 'health care information technology']
# shipping: ['shipping', 'shipping broker industry', 'shopping']
# logistics company: ['logistics company', 'logistics']
# billing: ['billing']
# developer tools: ['developer tools', 'eda tools', 'web tools']
# nightclubs: ['nightclubs']
# speech recognition: ['speech recognition']
# graphics: ['graphics']
# small and medium businesses: ['small and medium businesses', 'offline businesses', 'wine and spirits', 'oil and gas', 'local businesses']
# anything capital intensive: ['anything capital intensive', 'venture capital']
# health diagnostics: ['health diagnostics', 'diagnostics', 'health care information technology', 'health care']
# b2b express delivery: ['b2b express delivery', 'b2b', 'delivery']
# genetic testing: ['genetic testing', 'testing']
# creative: ['creative', 'creative industries']
# ticketing: ['ticketing']
# meeting software: ['meeting software', 'software', 'embedded hardware and software']
# water: ['water', 'water purification']
# fertility: ['fertility']
# home owners: ['home owners']
# sms: ['sms', 'group sms']
# wholesale: ['wholesale']
# cosmetic surgery: ['cosmetic surgery']
# fmcg: ['fmcg']
# internet technology: ['internet technology', 'technology', 'internet', 'internet tv', 'health care information technology']
# voip: ['voip']
# gift card: ['gift card', 'gift registries']
# online rental: ['online rental', 'online video advertising', 'bridging online and offline']
# sensors: ['sensors']
# early stage it: ['early stage it', 'early-stage technology', 'energy it']
# early-stage technology: ['early-stage technology', 'technology', 'early stage it', 'health care information technology', '3d technology']
# robotics: ['robotics']
# pharmaceuticals: ['pharmaceuticals', 'mac']
# lingerie: ['lingerie']
# ebooks: ['ebooks', 'e-books', 'notebooks']
# clinical trials: ['clinical trials']
# privacy: ['privacy', 'data privacy']
# k-12 education: ['k-12 education', 'education', 'technical continuing education']
# collaborative consumption: ['collaborative consumption']
# web browsers: ['web browsers', 'web presence management', 'web cms']
# new technologies: ['new technologies']
# plumbers: ['plumbers']
# video conferencing: ['video conferencing', 'video', 'video chat', 'video games', 'mobile video']
# utility land vehicles: ['utility land vehicles']
# business productivity: ['business productivity', 'productivity']
# guides: ['guides']
# nfc: ['nfc']
# ipod touch: ['ipod touch']
# hospitals: ['hospitals']
# social buying: ['social buying', 'social media management', 'social media platforms', 'social media monitoring', 'private social networking']
# recreation: ['recreation']
# contact centers: ['contact centers']
# business travelers: ['business travelers', 'travel', 'business information systems']
# data integration: ['data integration', 'data center infrastructure', 'big data']
# business development: ['business development']
# human resource automation: ['human resource automation', 'auto', 'human resources', 'sales automation', 'home automation']
# match-making: ['match-making']
# proximity internet: ['proximity internet', 'internet', 'internet tv']
# engineering firms: ['engineering firms']
# dod/military: ['dod/military']
# incubators: ['incubators']
# mobile infrastructure: ['mobile infrastructure', 'mobile', 'infrastructure', 'mobile social', 'mobile search']
# diy: ['diy']
# local based services: ['local based services', 'local services', 'local', 'services', 'location based services']
# storage: ['storage', 'self storage', 'flash storage', 'energy storage']
# energy management: ['energy management', 'energy', 'energy it', 'intellectual asset management', 'industrial energy efficiency']
# parenting: ['parenting']
# craft beer: ['craft beer']
# security: ['security', 'physical security', 'mobile security', 'enterprise security', 'information security']
# customer support tools: ['customer support tools', 'eda tools', 'web tools']
# automated kiosk: ['automated kiosk', 'ios', 'auto']
# events: ['events']
# data center infrastructure: ['data center infrastructure', 'infrastructure', 'data integration', 'data centers', 'personal data']
# video streaming: ['video streaming', 'video', 'online video advertising', 'video chat']
# vending and concessions: ['vending and concessions', 'oil and gas']
# green consumer goods: ['green consumer goods', 'consumer goods', 'green', 'virtual goods']
# temporary staffing: ['temporary staffing']
# online gaming: ['online gaming', 'online video advertising', 'bridging online and offline', 'online dating']
# contests: ['contests']
# postal and courier services: ['postal and courier services', 'services', 'shared services', 'music services', 'local services']
# cad: ['cad']
# custom retail: ['custom retail', 'retail']
# quantitative marketing: ['quantitative marketing', 'app marketing']
# testing: ['testing', 'genetic testing', 'user testing']
# sextech: ['sextech']
# high tech: ['high tech', 'hi tech', 'renewable tech', 'high school students', 'tech field support']
# online shopping: ['online shopping', 'shopping', 'online video advertising', 'bridging online and offline']
# market research: ['market research', 'search']
# operating systems: ['operating systems', 'systems', 'business information systems']
# veterinary: ['veterinary']
# creative industries: ['creative industries', 'creative']
# hip hop: ['hip hop']
# social media management: ['social media management', 'social media', 'media', 'social media agent', 'mobile social']
# recipes: ['recipes']
# career management: ['career management', 'intellectual asset management']
# aerospace: ['aerospace']
# service industries: ['service industries']
# public transportation: ['public transportation', 'transportation', 'public safety']
# energy it: ['energy it', 'energy', 'early stage it', 'energy management', 'energy efficiency']
# cloud-based music: ['cloud-based music', 'music']
# document management: ['document management', 'intellectual asset management']
# certification test: ['certification test']
# technology: ['technology', '3d technology', 'deep information technology', 'retail technology', 'finance technology']
# internet marketing: ['internet marketing', 'internet', 'internet tv']
# gift exchange: ['gift exchange']
# personal branding: ['personal branding']
# contact management: ['contact management', 'intellectual asset management']
# archiving: ['archiving']
# field support services: ['field support services', 'services', 'music services', 'local services', 'bpo services']
# qr codes: ['qr codes']
# virtual currency: ['virtual currency']
# sales and marketing: ['sales and marketing', 'direct sales', 'embedded hardware and software', 'flash sales', 'biotechnology and semiconductor']
# home automation: ['home automation', 'auto', 'human resource automation', 'home decor']
# broadcasting: ['broadcasting']
# social media platforms: ['social media platforms', 'social media', 'media', 'mobile social', 'social games']
# machine learning: ['machine learning', 'mac']
# news: ['news', 'email newsletters', 'social news']
# enterprise application: ['enterprise application', 'application performance monitoring', 'enterprise 2.0']
# leisure: ['leisure']
# enterprise resource planning: ['enterprise resource planning', 'enterprise search', 'career planning', 'mobile enterprise', 'enterprise 2.0']
# music services: ['music services', 'services', 'music', 'postal and courier services', 'field support services']
# browser extensions: ['browser extensions']
# universities: ['universities']
# b2b: ['b2b', 'b2b express delivery']
# photo sharing: ['photo sharing']
# cloud security: ['cloud security', 'security']
# concerts: ['concerts']
# image recognition: ['image recognition', 'face recognition']
# hi tech: ['hi tech', 'high tech', 'renewable tech', 'tech field support']
# film distribution: ['film distribution', 'distribution', 'film']
# file sharing: ['file sharing']
# emerging markets: ['emerging markets']
# edutainment: ['edutainment']
# network security: ['network security', 'security']
# opinions: ['opinions']
# funeral industry: ['funeral industry', 'health services industry', 'shipping broker industry']
# mobile coupons: ['mobile coupons', 'mobile', 'coupons', 'mobile software tools', 'mobile infrastructure']
# multi-level marketing: ['multi-level marketing', 'app marketing']
# local services: ['local services', 'local based services', 'local', 'services', 'postal and courier services']
# cars: ['cars']
# gift registries: ['gift registries', 'gift card']
# biofuels: ['biofuels', 'fuels']
# search marketing: ['search marketing', 'search']
# nutrition: ['nutrition']
# charter schools: ['charter schools', 'art']
# mobile health: ['mobile health', 'mobile', 'mobile software tools', 'mobile infrastructure', 'social + mobile + local']
# transportation: ['transportation', 'public transportation']
# internet tv: ['internet tv', 'internet', 'internet of things', 'internet technology', 'proximity internet']
# digital rights management: ['digital rights management', 'it management', 'task management', 'digital media', 'fleet management']
# gadget: ['gadget']
# furniture: ['furniture']
# interior design: ['interior design', 'design', 'web design']
# civil engineers: ['civil engineers']
# wireless: ['wireless']
# south east asia: ['south east asia']
# cyber security: ['cyber security', 'cyber', 'security']
# virtual worlds: ['virtual worlds']
# electronics: ['electronics', 'consumer electronics']
# teenagers: ['teenagers']
# trusted networks: ['trusted networks']
# energy efficiency: ['energy efficiency', 'industrial energy efficiency', 'energy', 'energy it']
# university students: ['university students', 'all students']
# subscription businesses: ['subscription businesses']
# discounts: ['discounts']
# families: ['families']
# intellectual asset management: ['intellectual asset management', 'energy management', 'career management', 'document management', 'contact management']
# artists globally: ['artists globally', 'art']
# venture capital: ['venture capital', 'anything capital intensive']
# it management: ['it management', 'web presence management', 'social media management', 'digital rights management', 'intellectual asset management']
# gas: ['gas', 'natural gas uses', 'oil & gas', 'oil and gas']
# government innovation: ['government innovation']
# specialty chemicals: ['specialty chemicals', 'chemicals']
# senior citizens: ['senior citizens']
# online travel: ['online travel', 'travel', 'online video advertising', 'bridging online and offline']
# hardware + software: ['hardware + software', 'hardware', 'software', 'embedded hardware and software']
# low bid auctions: ['low bid auctions', 'auctions']
# notebooks: ['notebooks', 'ebooks']
# content discovery: ['content discovery', 'content', 'content delivery']
# exercise: ['exercise']
# p2p money transfer: ['p2p money transfer']
# service providers: ['service providers', 'internet service providers']
# photography: ['photography']
# analytics: ['analytics', 'business analytics', 'text analytics', 'big data analytics', 'mobile analytics']
# e-commerce: ['e-commerce', 'e-commerce platforms', 'mobile commerce', 'social commerce', 'local commerce']
# kids: ['kids']
# recycling: ['recycling']
# presentations: ['presentations']
# email newsletters: ['email newsletters', 'news', 'email']
# polling: ['polling']
# salesforce killers: ['salesforce killers']
# greentech: ['greentech', 'green']
# direct sales: ['direct sales', 'direct advertising', 'sales and marketing']
# eyewear: ['eyewear']
# landscaping: ['landscaping']
# organic food: ['organic food', 'organic']
# systems: ['systems', 'intelligent systems', 'operating systems', 'business information systems', 'unmanned air systems']
# racing: ['racing', 'tracking']
# organic: ['organic', 'organic food']
# augmented reality: ['augmented reality']
# ipad: ['ipad']
# college recruiting: ['college recruiting', 'recruiting']
# outdoors: ['outdoors']
# mobile: ['mobile', 'mobile security', 'mobile social', 'mobile search', 'mobile software tools']
# all students: ['all students', 'university students', 'high school students']
# accounting: ['accounting']
# assisitive technology: ['assisitive technology', 'technology', 'health care information technology', '3d technology']
# text analytics: ['text analytics', 'analytics']
# outsourcing: ['outsourcing']
# prediction markets: ['prediction markets', 'ict', 'all markets']
# data centers: ['data centers', 'data center infrastructure', 'big data analytics', 'cloud data services', 'data visualization']
# printing: ['printing', '3d printing']
# corporate it: ['corporate it', 'clean technology it', 'corporate wellness', 'it and cybersecurity', 'corporate training']
# shoes: ['shoes']
# vertical search: ['vertical search', 'search']
# e-commerce platforms: ['e-commerce platforms', 'e-commerce', 'e-books']
# college campuses: ['college campuses']
# smart building: ['smart building', 'art']
# podcast: ['podcast']
# google apps: ['google apps', 'apps']
# enterprise hardware: ['enterprise hardware', 'hardware', 'embedded hardware and software']
# interest graph: ['interest graph']
# audio: ['audio', 'audiobooks']
# fraud detection: ['fraud detection']
# dietary supplements: ['dietary supplements']
# casual games: ['casual games', 'games', 'game']
# gamification: ['gamification']
# hdtv: ['hdtv']
# peer-to-peer: ['peer-to-peer', 'guide to nightlife']
# mothers: ['mothers']
# point of sale: ['point of sale']
# social media monitoring: ['social media monitoring', 'social media', 'media', 'mobile social', 'social games']
# gps: ['gps']
# communications infrastructure: ['communications infrastructure', 'infrastructure']
# chemicals: ['chemicals', 'specialty chemicals']
# doctors: ['doctors']
# fitness: ['fitness']
# private social networking: ['private social networking', 'networking', 'mobile social', 'social games', 'social buying']
# advanced materials: ['advanced materials']
# internet: ['internet', 'internet tv', 'internet of things', 'internet technology', 'proximity internet']
# material science: ['material science']
# baby safety: ['baby safety']
# electric vehicles: ['electric vehicles']
# social media marketing: ['social media marketing', 'social media', 'media', 'mobile social', 'social games']
# tea: ['tea', 'teaching stem concepts', 'teachers']
# jewelry: ['jewelry']
# realtors: ['realtors']
# cooking: ['cooking', 'coworking']
# edtech: ['edtech']
# english-speaking: ['english-speaking']
# writers: ['writers']
# travel: ['travel', 'business travelers', 'online travel', 'space travel', 'travel & tourism']
# social fundraising: ['social fundraising', 'social games', 'social news', 'social media', 'social crm']
# sports stadiums: ['sports stadiums', 'sports']
# film production: ['film production', 'film']
# pets: ['pets']
# mass customization: ['mass customization']
# rental housing: ['rental housing']
# air pollution control: ['air pollution control']
# social media agent: ['social media agent', 'social media', 'media', 'social media management', 'social games']
# price comparison: ['price comparison']
# personal data: ['personal data', 'data center infrastructure', 'data center automation', 'big data']
# cloud computing: ['cloud computing']
# sporting goods: ['sporting goods']
# application performance monitoring: ['application performance monitoring', 'enterprise application', 'performance marketing', 'application platforms']
# personalization: ['personalization']
# online education: ['online education', 'education', 'online video advertising', 'bridging online and offline', 'technical continuing education']
# water purification: ['water purification', 'water']
# clean technology it: ['clean technology it', 'clean technology', 'technology', 'clean energy', 'energy it']
# design: ['design', 'user experience design', 'interface design', 'interior design', 'experience design']
# west africa: ['west africa', 'east africa']
# rural energy: ['rural energy', 'energy', 'industrial energy efficiency']
# infrastructure builders: ['infrastructure builders', 'infrastructure']
# industrial automation: ['industrial automation', 'industrial', 'auto']
# sex industry: ['sex industry', 'entertainment industry', 'health services industry', 'shipping broker industry']
# entrepreneur: ['entrepreneur', 'social entrepreneurship']
# hospitality: ['hospitality']
# local search: ['local search', 'search', 'local', 'social search', 'local based services']
# auto: ['auto', 'sales automation', 'automotive', 'human resource automation', 'automated kiosk']
# social entrepreneurship: ['social entrepreneurship', 'entrepreneur', 'mobile social', 'social games', 'social buying']
# databases: ['databases']
# game mechanics: ['game mechanics', 'game', 'video game tournaments']
# indians: ['indians']
# mens specific: ['mens specific']
# embedded hardware and software: ['embedded hardware and software', 'hardware', 'software', 'enterprise software', 'meeting software']
# crowdsourcing: ['crowdsourcing']
# social innovation: ['social innovation', 'social news', 'social crm']
# task management: ['task management', 'risk management', 'web presence management', 'social media management', 'digital rights management']
# tv station: ['tv station']
# online identity: ['online identity', 'identity', 'online video advertising', 'bridging online and offline']
# fuel cells: ['fuel cells']
# business services: ['business services', 'services', 'postal and courier services', 'business information systems', 'product development services']
# virtual workforces: ['virtual workforces']
# diabetes: ['diabetes']
# virtual goods: ['virtual goods', 'green consumer goods']
# video: ['video', 'video game tournaments', 'video conferencing', 'video streaming', 'online video advertising']
# alumni: ['alumni']
# online video advertising: ['online video advertising', 'advertising', 'video', 'online rental', 'video streaming']
# industrial energy efficiency: ['industrial energy efficiency', 'industrial', 'energy efficiency', 'energy', 'clean energy']
# search: ['search', 'enterprise search', 'mobile search', 'market research', 'search marketing']
# local: ['local', 'local based services', 'local services', 'local search', 'social + mobile + local']
# unifed communications: ['unifed communications']
# social search: ['social search', 'search', 'local search', 'social media management', 'social media platforms']
# underserved children: ['underserved children']
# alternative medicine: ['alternative medicine']
# information technology: ['information technology', 'deep information technology', 'technology', 'health care information technology', '3d technology']
# logistics: ['logistics', 'logistics company']
# corporate wellness: ['corporate wellness', 'corporate it']
# employment: ['employment']
# disruptive models: ['disruptive models']
# medication adherence: ['medication adherence']
# general public worldwide: ['general public worldwide', 'public safety', 'public relations']
# web cms: ['web cms', 'web presence management', 'web browsers', 'web development', 'web hosting']
# medical professionals: ['medical professionals', 'medical']
# language learning: ['language learning', 'natural language processing']
# home & garden: ['home & garden']
# publishing: ['publishing']
# computer vision: ['computer vision', 'human computer interaction']
# tracking: ['tracking', 'racing']
# m2m: ['m2m']
# business information systems: ['business information systems', 'systems', 'business analytics', 'business travelers', 'operating systems']
# bpo services: ['bpo services', 'services', 'information services', 'local based services', 'postal and courier services']
# services: ['services', 'shared services', 'information services', 'local based services', 'postal and courier services']
# skate wear: ['skate wear']
# vacation rentals: ['vacation rentals']
# angels: ['angels']
# real estate investors: ['real estate investors', 'real estate', 'real time']
# bitcoin: ['bitcoin']
# parking: ['parking']
# bridging online and offline: ['bridging online and offline', 'online rental', 'online gaming', 'online shopping', 'online travel']
# domains: ['domains']
# email: ['email', 'email marketing', 'email newsletters']
# construction: ['construction']
# manufacturing: ['manufacturing', 'semiconductor manufacturing equipment']
# aquaculture: ['aquaculture']
# pervasive computing: ['pervasive computing']
# biotechnology: ['biotechnology', 'biotechnology and semiconductor', 'technology']
# virtualization: ['virtualization', 'visualization']
# offline businesses: ['offline businesses', 'small and medium businesses', 'bridging online and offline']
# property management: ['property management', 'intellectual asset management', 'project management']
# reputation: ['reputation']
# digital media: ['digital media', 'media', 'social media management', 'social media platforms', 'digital rights management']
# charity: ['charity']
# biomass power generation: ['biomass power generation', 'generation y-z', 'lead generation']
# video on demand: ['video on demand', 'video', 'online video advertising', 'video chat']
# identity: ['identity', 'online identity', 'identity management']
# optical communications: ['optical communications']
# assisted living: ['assisted living']
# saas: ['saas']
# apps: ['apps', 'reading apps', 'google apps']
# gambling: ['gambling']
# internet infrastructure: ['internet infrastructure', 'internet', 'infrastructure', 'internet tv', 'china internet']
# big data analytics: ['big data analytics', 'analytics', 'big data', 'data centers', 'data privacy']
# sustainability: ['sustainability']
# mobile analytics: ['mobile analytics', 'analytics', 'mobile']
# flowers: ['flowers']
# space travel: ['space travel', 'travel']
# renewable energies: ['renewable energies']
# predictive analytics: ['predictive analytics', 'analytics', 'ict']
# senior health: ['senior health', 'health care information technology', 'health and insurance', 'mobile emergency&health', 'health services industry']
# app discovery: ['app discovery']
# experience design: ['experience design', 'user experience design', 'design', 'web design']
# wine and spirits: ['wine and spirits', 'small and medium businesses', 'postal and courier services', 'embedded hardware and software', 'bridging online and offline']
# cable: ['cable']
# 3d: ['3d', '3d printing', '3d technology']
# q&a: ['q&a']
# building owners: ['building owners']
# product design: ['product design', 'design', 'user experience design', 'product development services', 'new product development']
# coupons: ['coupons', 'mobile coupons', 'local coupons']
# infrastructure: ['infrastructure', 'cloud infrastructure', 'mobile infrastructure', 'data center infrastructure', 'communications infrastructure']
# social network media: ['social network media', 'media', 'mobile social', 'social games', 'social buying']
# video processing: ['video processing', 'video', 'online video advertising', 'video chat', 'natural language processing']
# independent pharmacies: ['independent pharmacies', 'mac']
# farmers market: ['farmers market', 'internet radio market']
# adaptive equipment: ['adaptive equipment', 'semiconductor manufacturing equipment']
# wearables: ['wearables']
# development platforms: ['development platforms']
# developer apis: ['developer apis']
# motors: ['motors']
# video chat: ['video chat', 'video', 'chat', 'video game tournaments', 'video conferencing']
# consumer internet: ['consumer internet', 'internet', 'internet tv', 'internet service providers']
# indoor positioning: ['indoor positioning']
# internet radio market: ['internet radio market', 'internet', 'internet tv', 'farmers market', 'china internet']
# serious games: ['serious games', 'games', 'game']
# credit: ['credit', 'credit cards']
# mmo games: ['mmo games', 'games', 'game', 'educational games']
# social + mobile + local: ['social + mobile + local', 'mobile', 'local', 'mobile security', 'mobile social']
# wind: ['wind', 'windows phone 7']
# health care information technology: ['health care information technology', 'technology', 'information technology', 'health care', 'deep information technology']
# demographies: ['demographies']
# surveys: ['surveys']
# baby accessories: ['baby accessories']
# collaboration: ['collaboration']
# auctions: ['auctions', 'low bid auctions', 'online auctions']
# enterprises: ['enterprises', 'micro-enterprises', 'mobile enterprise']
# music: ['music', 'cloud-based music', 'music services', 'music education', 'music venues']
# fantasy sports: ['fantasy sports', 'sports']
# tv production: ['tv production']
# healthcare services: ['healthcare services', 'services', 'bpo services']
# fashion: ['fashion']
# energy: ['energy', 'clean energy', 'energy management', 'energy it', 'energy efficiency']
# digital entertainment: ['digital entertainment', 'entertainment', 'digital media']
# invention: ['invention']
# cloud data services: ['cloud data services', 'services', 'cloud gaming', 'data centers', 'bpo services']
# user interface: ['user interface', 'user experience design']
# distribution: ['distribution', 'film distribution', 'electrical distribution']
# comparison shopping: ['comparison shopping', 'shopping']
# skill gaming: ['skill gaming']
# taxis: ['taxis']
# rfid: ['rfid']
# ediscovery: ['ediscovery']
# social news: ['social news', 'news', 'social bookmarking', 'social media management', 'social media platforms']
# eda tools: ['eda tools', 'mobile software tools', 'developer tools', 'customer support tools']
# advice: ['advice']
# consumer lending: ['consumer lending']
# licensing: ['licensing']
# social opinion platform: ['social opinion platform', 'mobile social', 'social games', 'social buying', 'social search']
# shopping: ['shopping', 'online shopping', 'comparison shopping', 'mobile shopping', 'shipping']
# credit cards: ['credit cards', 'credit']
# marketing automation: ['marketing automation', 'auto', 'app marketing']
# active lifestyle: ['active lifestyle', 'lifestyle']
# hardware: ['hardware', 'communications hardware', 'hardware + software', 'enterprise hardware', 'embedded hardware and software']
# farming: ['farming']
# open source: ['open source']
# bio-pharm: ['bio-pharm']
# promotional: ['promotional']
# psychology: ['psychology']
# fleet management: ['fleet management', 'event management', 'digital rights management', 'intellectual asset management', 'vulnerability management']
# self storage: ['self storage', 'storage']
# fruit: ['fruit']
# environmental innovation: ['environmental innovation']
# banking: ['banking']
# women: ['women']
# call center automation: ['call center automation', 'auto', 'data center automation']
# beauty: ['beauty']
# monetization: ['monetization']
# music education: ['music education', 'music', 'education', 'independent music labels', 'technical continuing education']
# data visualization: ['data visualization', 'visualization', 'data centers', 'data privacy', 'big data']
# building products: ['building products']
# music venues: ['music venues', 'music', 'independent music labels']
# commercial real estate: ['commercial real estate', 'real estate', 'real time']
# social commerce: ['social commerce', 'local commerce', 'social media management', 'e-commerce', 'social media monitoring']
# paas: ['paas']
# law enforcement: ['law enforcement']
# consumers: ['consumers']
# carbon: ['carbon']
# natural gas uses: ['natural gas uses', 'gas', 'oil & gas', 'natural language processing']
# product development services: ['product development services', 'services', 'shared services', 'music services', 'local services']
# social recruiting: ['social recruiting', 'recruiting', 'social news', 'social crm']
# productivity software: ['productivity software', 'software', 'productivity']
# video games: ['video games', 'games', 'video', 'game', 'video game tournaments']
# flash sales: ['flash sales', 'sales and marketing']
# networking: ['networking', 'private social networking', 'professional networking']
# medical devices: ['medical devices', 'medical']
# consumer goods: ['consumer goods', 'green consumer goods']
# it and cybersecurity: ['it and cybersecurity', 'cyber', 'security', 'energy it', 'it management']
# social media: ['social media', 'social media management', 'social media platforms', 'social media monitoring', 'social media marketing']
# visual search: ['visual search', 'search']
# forums: ['forums']
# performance marketing: ['performance marketing', 'application performance monitoring', 'app marketing']
# risk management: ['risk management', 'task management', 'web presence management', 'social media management', 'digital rights management']
# public relations: ['public relations', 'general public worldwide']
# digital signage: ['digital signage', 'digital rights management']
# twitter applications: ['twitter applications']
# high school students: ['high school students', 'high tech', 'all students', 'high schools']
# local commerce: ['local commerce', 'local', 'social commerce', 'social + mobile + local', 'e-commerce']
# media: ['media', 'social media management', 'social media platforms', 'social media monitoring', 'social media marketing']
# professional services: ['professional services', 'services', 'music services', 'local services', 'bpo services']
# social television: ['social television', 'television', 'social news', 'social crm']
# insurance companies: ['insurance companies', 'insurance']
# portals: ['portals']
# intellectual property: ['intellectual property']
# health and insurance: ['health and insurance', 'insurance', 'mobile health', 'embedded hardware and software', 'senior health']
# coffee: ['coffee']
# brewing: ['brewing']
# stock exchanges: ['stock exchanges']
# lifestyle products: ['lifestyle products', 'lifestyle']
# micro-enterprises: ['micro-enterprises', 'enterprises']
# mobile payments: ['mobile payments', 'mobile', 'payments', 'social + mobile + local', 'mobile emergency&health']
# musical instruments: ['musical instruments', 'music']
# startups: ['startups', 'art', 'radical breakthrough startups']
# web development: ['web development', 'web presence management', 'web cms', 'product development services', 'web tools']
# social media advertising: ['social media advertising', 'advertising', 'social media', 'media', 'mobile social']
# religion: ['religion']
# finance: ['finance', 'finance technology', 'personal finance']
# lead generation: ['lead generation', 'biomass power generation']
# chat: ['chat', 'video chat']
# spam filtering: ['spam filtering']
# data privacy: ['data privacy', 'privacy', 'data center infrastructure', 'big data analytics', 'cloud data services']
# residential solar: ['residential solar', 'solar']
# corporate training: ['corporate training', 'training', 'corporate it']
# real estate: ['real estate', 'real estate investors', 'commercial real estate']
# crm: ['crm', 'social crm']
# advertising platforms: ['advertising platforms', 'advertising']
# windows phone 7: ['windows phone 7', 'wind']
# mobile enterprise: ['mobile enterprise', 'mobile', 'enterprise resource planning', 'enterprises']
# mechanical solutions: ['mechanical solutions']
# first aid: ['first aid']
# innovation management: ['innovation management', 'it management']
# mhealth: ['mhealth']
# specialty foods: ['specialty foods']
# cryptocurrency: ['cryptocurrency']
# drones: ['drones']
# dental: ['dental']
# television: ['television', 'social television']
# direct marketing: ['direct marketing']
# maps: ['maps']
# real time: ['real time', 'real estate investors', 'commercial real estate']
# data center automation: ['data center automation', 'auto', 'data centers', 'personal data', 'call center automation']
# biotechnology and semiconductor: ['biotechnology and semiconductor', 'technology', 'biotechnology', 'sales and marketing', 'wine and spirits']
# web tools: ['web tools', 'web presence management', 'mobile software tools', 'developer tools', 'customer support tools']
# child care: ['child care', 'health care information technology']
# supply chain management: ['supply chain management', 'it management', 'task management', 'risk management', 'lead management']
# private school: ['private school', 'private social networking']
# minerals: ['minerals']
# application platforms: ['application platforms', 'application performance monitoring']
# web hosting: ['web hosting', 'web presence management', 'web cms']
# mining technologies: ['mining technologies', 'data mining']
# guide to nightlife: ['guide to nightlife', 'nightlife', 'peer-to-peer']
# diagnostics: ['diagnostics', 'health diagnostics']
# marketplaces: ['marketplaces']
# seo: ['seo']
# watch: ['watch']
# online auctions: ['online auctions', 'auctions', 'online video advertising', 'bridging online and offline']
# flash storage: ['flash storage', 'storage']
# sponsorship: ['sponsorship']
# app stores: ['app stores']
# e-books: ['e-books', 'ebooks', 'e-commerce platforms']
# coworking: ['coworking', 'cooking']
# journalism: ['journalism']
# reviews and recommendations: ['reviews and recommendations', 'wine and spirits', 'oil and gas']
# test and measurement: ['test and measurement', 'embedded hardware and software', 'biotechnology and semiconductor', 'oil and gas']
# ride sharing: ['ride sharing']
# medical: ['medical', 'medical professionals', 'medical devices']
# home renovation: ['home renovation', 'home decor']
# cannabis: ['cannabis']
# knowledge management: ['knowledge management', 'it management']
# algorithms: ['algorithms']
# food processing: ['food processing', 'natural language processing']
# data security: ['data security', 'security', 'information security', 'data center infrastructure', 'data center automation']
# new product development: ['new product development', 'product design', 'product development services', 'web development', 'product search']
# local coupons: ['local coupons', 'local', 'coupons', 'local based services', 'social + mobile + local']
# recruiting: ['recruiting', 'college recruiting', 'social recruiting']
# health and wellness: ['health and wellness', 'embedded hardware and software', 'health care information technology', 'biotechnology and semiconductor', 'health care']
# trading: ['trading']
# registrars: ['registrars']
# skill assessment: ['skill assessment']
# oil & gas: ['oil & gas', 'oil and gas', 'oil', 'gas', 'natural gas uses']
# audiobooks: ['audiobooks', 'audio']
# educational games: ['educational games', 'games', 'game', 'education', 'mmo games']
# made in italy: ['made in italy', 'in-flight entertainment']
# big data: ['big data', 'big data analytics', 'data integration', 'data center infrastructure', 'data centers']
# software: ['software', 'enterprise software', 'mobile software tools', 'meeting software', 'hardware + software']
# agriculture: ['agriculture']
# advertising exchanges: ['advertising exchanges', 'advertising']
# photo editing: ['photo editing']
# entertainment industry: ['entertainment industry', 'entertainment', 'sex industry', 'heavy industry']
# textbooks: ['textbooks']
# web design: ['web design', 'design', 'user experience design', 'interface design', 'web presence management']
# freemium: ['freemium']
# colleges: ['colleges']
# social investing: ['social investing', 'private social networking', 'social media advertising', 'social crm']
# virtual desktop: ['virtual desktop']
# blogging platforms: ['blogging platforms']
# limousines: ['limousines']
# tutoring: ['tutoring']
# legal: ['legal']
# messaging: ['messaging']
# textiles: ['textiles']
# mobile games: ['mobile games', 'games', 'mobile', 'game', 'mobile software tools']
# handmade: ['handmade']
# project management: ['project management', 'intellectual asset management', 'property management']
# green building: ['green building', 'green']
# event management: ['event management', 'fleet management', 'digital rights management', 'intellectual asset management', 'vulnerability management']
# designers: ['designers', 'design']
# advertising networks: ['advertising networks', 'advertising']
# consulting: ['consulting']
# rehabilitation: ['rehabilitation']
# semiconductor manufacturing equipment: ['semiconductor manufacturing equipment', 'manufacturing', 'adaptive equipment', 'golf equipment']
# insurance: ['insurance', 'insurance companies', 'health and insurance']
# telecommunications: ['telecommunications']
# solar: ['solar', 'residential solar', 'commercial solar', 'concentrated solar power']
# cause marketing: ['cause marketing']
# 3d technology: ['3d technology', 'technology', '3d', 'deep information technology', 'early-stage technology']
# impact investing: ['impact investing']
# semiconductors: ['semiconductors', 'biotechnology and semiconductor']
# elderly: ['elderly']
# graphic design: ['graphic design', 'design', 'user experience design']
# innovation engineering: ['innovation engineering']
# debt collecting: ['debt collecting']
# teaching stem concepts: ['teaching stem concepts', 'tea']
# mobile commerce: ['mobile commerce', 'e-commerce', 'mobile', 'social + mobile + local', 'mobile emergency&health']
# investment management: ['investment management', 'it management']
# employer benefits programs: ['employer benefits programs', 'loyalty programs']
# face recognition: ['face recognition', 'image recognition']
# curated web: ['curated web', 'web presence management', 'web cms']
# identity management: ['identity management', 'identity', 'intellectual asset management']
# mobile emergency&health: ['mobile emergency&health', 'mobile', 'mobile security', 'mobile social', 'mobile search']
# geospatial: ['geospatial']
# financial exchanges: ['financial exchanges']
# lifestyle businesses: ['lifestyle businesses', 'lifestyle']
# smart grid: ['smart grid', 'art']
# online dating: ['online dating', 'online video advertising', 'bridging online and offline', 'online gaming']
# customer service: ['customer service', 'internet service providers']
# location based services: ['location based services', 'services', 'local based services', 'shared services', 'music services']
# independent music labels: ['independent music labels', 'independent music', 'music', 'music services', 'music education']
# synchronization: ['synchronization']
# sns: ['sns']
# navigation: ['navigation']
# tech field support: ['tech field support', 'high tech', 'hi tech', 'non-tech']
# product search: ['product search', 'search', 'product development services', 'new product development']
# technical continuing education: ['technical continuing education', 'education', 'k-12 education', 'online education', 'music education']
# subscription service: ['subscription service']
# mobility: ['mobility']
# content creators: ['content creators', 'content']
# tourism: ['tourism', 'travel & tourism']
# brokers: ['brokers']
# lead management: ['lead management', 'web presence management', 'social media management', 'digital rights management', 'intellectual asset management']
# health services industry: ['health services industry', 'services', 'boating industry', 'shared services', 'music services']
# vulnerability management: ['vulnerability management', 'it management', 'task management', 'fleet management', 'risk management']
# visualization: ['visualization', 'data visualization', 'virtualization']
# cloud management: ['cloud management', 'digital rights management', 'intellectual asset management', 'vulnerability management']
# shipping broker industry: ['shipping broker industry', 'shipping', 'boating industry', 'funeral industry', 'sex industry']
# high schools: ['high schools', 'high school students']
# personal health: ['personal health', 'health care information technology', 'mobile emergency&health', 'health services industry', 'electronic health records']
# franchises: ['franchises']
# bicycles: ['bicycles']
# staffing firms: ['staffing firms']
# non-tech: ['non-tech', 'renewable tech', 'tech field support']
# hotels: ['hotels']
# homeland security: ['homeland security', 'security']
# user testing: ['user testing', 'testing', 'user experience design']
# weddings: ['weddings']
# home decor: ['home decor', 'home automation', 'home renovation']
# gold: ['gold']
# delivery: ['delivery', 'content delivery', 'b2b express delivery']
# optimization: ['optimization', 'labor optimization']
# fuels: ['fuels', 'biofuels']
# remediation: ['remediation', 'media']
# ventures for good: ['ventures for good']
# kinect: ['kinect']
# batteries: ['batteries']
# fpga: ['fpga']
# electrical distribution: ['electrical distribution', 'distribution']
# online scheduling: ['online scheduling', 'bridging online and offline']
# unmanned air systems: ['unmanned air systems', 'systems']
# private corrections: ['private corrections']
# golf equipment: ['golf equipment', 'semiconductor manufacturing equipment']
# group buying: ['group buying']
# china internet: ['china internet', 'internet', 'internet infrastructure', 'internet radio market', 'internet service providers']
# humanitarian: ['humanitarian']
# productivity: ['productivity', 'business productivity', 'productivity software']
# wealth management: ['wealth management', 'intellectual asset management', 'waste management']
# elder care: ['elder care', 'health care information technology']
# ad targeting: ['ad targeting']
# software compliance: ['software compliance', 'software', 'embedded hardware and software']
# heavy industry: ['heavy industry', 'entertainment industry', 'health services industry', 'shipping broker industry']
# nonprofits: ['nonprofits', 'non profit']
# natural language processing: ['natural language processing', 'natural resources', 'language learning', 'video processing', 'natural gas uses']
# energy storage: ['energy storage', 'storage', 'energy', 'energy it', 'industrial energy efficiency']
# outdoor advertising: ['outdoor advertising', 'advertising']
# social activists: ['social activists', 'private social networking', 'social media advertising', 'social crm']
# game: ['game', 'video game tournaments', 'social games', 'casual games', 'game mechanics']
# independent music: ['independent music', 'independent music labels', 'music']
# internet service providers: ['internet service providers', 'service providers', 'internet', 'internet tv', 'consumer internet']
# self development: ['self development', 'product development services']
# clean technology: ['clean technology', 'clean technology it', 'technology', 'deep information technology', 'health care information technology']
# startup histrionics: ['startup histrionics', 'art']
# transaction processing: ['transaction processing']
# lotteries: ['lotteries']
# lifestyle: ['lifestyle', 'active lifestyle', 'lifestyle products', 'lifestyle businesses']
# electronic health records: ['electronic health records', 'mobile health', 'senior health', 'personal health', 'health care']
# labor optimization: ['labor optimization', 'optimization']
# comics: ['comics']
# rim: ['rim']
# travel & tourism: ['travel & tourism', 'travel', 'tourism']
# iphone: ['iphone']
# semantic search: ['semantic search', 'search']
# financial services: ['financial services', 'services', 'postal and courier services', 'bpo services', 'product development services']
# webos: ['webos']
# health care: ['health care', 'health care information technology', 'health diagnostics', 'health and insurance', 'health and wellness']
# training: ['training', 'corporate training']
# computers: ['computers']
# payments: ['payments', 'mobile payments']
# consumer electronics: ['consumer electronics', 'electronics']
# hunting industry: ['hunting industry', 'health services industry', 'shipping broker industry']
# pre seed: ['pre seed']
# video editing: ['video editing', 'video', 'video game tournaments', 'online video advertising']
# procurement: ['procurement']
# cloud infrastructure: ['cloud infrastructure', 'infrastructure', 'cloud gaming']
# rapidly expanding: ['rapidly expanding']
# moneymaking: ['moneymaking']
# mobile advertising: ['mobile advertising', 'advertising', 'mobile', 'mobile games', 'mobile video']
# facebook applications: ['facebook applications']
# mobile video: ['mobile video', 'mobile', 'video', 'mobile software tools', 'video game tournaments']
# semantic web: ['semantic web', 'web presence management', 'web cms']
# professional networking: ['professional networking', 'networking']
# spas: ['spas']
# toys: ['toys']
# governments: ['governments']
# mobile shopping: ['mobile shopping', 'mobile', 'shopping', 'social + mobile + local', 'mobile emergency&health']
# restaurants: ['restaurants']
# business intelligence: ['business intelligence']
# loyalty programs: ['loyalty programs', 'employer benefits programs']
# teachers: ['teachers', 'tea']
# radical breakthrough startups: ['radical breakthrough startups', 'startups']
# education: ['education', 'k-12 education', 'online education', 'music education', 'educational games']
# data mining: ['data mining', 'data center infrastructure', 'big data analytics', 'cloud data services', 'data visualization']
# celebrity: ['celebrity']
# mobile devices: ['mobile devices', 'mobile', 'mobile software tools', 'mobile infrastructure', 'social + mobile + local']
# performing arts: ['performing arts', 'art']
# pc gaming: ['pc gaming', 'freetoplay gaming', 'console gaming']
# linux: ['linux']
# niche specific: ['niche specific']
# social business: ['social business', 'social media management', 'social media monitoring', 'private social networking', 'social entrepreneurship']
# animal feed: ['animal feed']
# commercial solar: ['commercial solar', 'solar', 'concentrated solar power']
# enterprise 2.0: ['enterprise 2.0', 'enterprise purchasing', 'enterprise application', 'enterprise resource planning']
# oil and gas: ['oil and gas', 'oil & gas', 'oil', 'gas', 'small and medium businesses']
# charities: ['charities']
# ict: ['ict', 'prediction markets', 'predictive analytics']
# swimming: ['swimming']
# concentrated solar power: ['concentrated solar power', 'solar', 'commercial solar']
# sailing community: ['sailing community']
# social travel: ['social travel', 'travel', 'social media management', 'social media platforms', 'social media monitoring']
# therapeutics: ['therapeutics']
# social crm: ['social crm', 'crm', 'social bookmarking', 'social media management', 'social media platforms']
# local advertising: ['local advertising', 'advertising', 'local']
# musicians: ['musicians', 'music']
# waste management: ['waste management', 'digital rights management', 'intellectual asset management', 'vulnerability management', 'wealth management']
# uv leds: ['uv leds']
# timeshares: ['timeshares']
# app marketing: ['app marketing', 'quantitative marketing', 'multi-level marketing', 'social media marketing', 'marketing automation']
# estimation and quoting: ['estimation and quoting', 'oil and gas']
# adventure travel: ['adventure travel', 'travel']
# brand marketing: ['brand marketing']
# collectibles: ['collectibles']
# groceries: ['groceries']
# lasers: ['lasers']
# sports: ['sports', 'sports stadiums', 'fantasy sports']
# local businesses: ['local businesses', 'local', 'small and medium businesses']
# online reservations: ['online reservations']
# personal finance: ['personal finance', 'finance']
# iaas: ['iaas']
# diving: ['diving']
# biometrics: ['biometrics']
# specialty retail: ['specialty retail', 'retail']
# mac: ['mac', 'pharmaceuticals', 'machine learning', 'independent pharmacies']

# %% [markdown]
# __Не очень хороший результат. Например task management: ['task management', 'risk management', 'web presence management', 'social media management', 'vulnerability management'], eda tools: ['eda tools', 'developer tools', 'mobile software tools', 'customer support tools']__

# %% [markdown]
# __Попробуем векторизацию с помощью TF-IDF (Term Frequency-Inverse Document Frequency) и KMEANS__

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(unique_categories)

num_clusters = 20
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(tfidf_matrix)

cluster_labels = kmeans.labels_
clustered_categories = pd.DataFrame({'category': unique_categories, 'cluster': cluster_labels})

print(clustered_categories.sort_values(by='cluster').head(60))
# Out:
#                           category  cluster
# 319                          shoes        0
# 749        electrical distribution        1
# 236              film distribution        1
# 511                   distribution        1
# 739                     home decor        2
# 421                  home & garden        2
# 126                    home owners        2
# 219                home automation        2
# 640                home renovation        2
# 727               cloud management        3
# 698          investment management        3
# 702            identity management        3
# 725       vulnerability management        3
# 207            document management        3
# 758              wealth management        3
# 723                lead management        3
# 275                  it management        3
# 533               fleet management        3
# 679               event management        3
# 677             project management        3
# 255      digital rights management        3
# 566                risk management        3
# 172              energy management        3
# 642           knowledge management        3
# 618        supply chain management        3
# 393                task management        3
# 199        social media management        3
# 201              career management        3
# 213             contact management        3
# 272  intellectual asset management        3
# 445            property management        3
# 604          innovation management        3
# 835               waste management        3
# 258                interior design        4
# 47                interface design        4
# 31          user experience design        4
# 693                 graphic design        4
# 467              experience design        4
# 375                         design        4
# 473                 product design        4
# 558                     networking        5
# 545                   music venues        5
# 410           alternative medicine        5
# 547                social commerce        5
# 562                   social media        5
# 548                           paas        5
# 549                law enforcement        5
# 409           underserved children        5
# 550                      consumers        5
# 551                         carbon        5
# 559                medical devices        5
# 553   product development services        5
# 554              social recruiting        5
# 557                    flash sales        5
# 560                 consumer goods        5
# 427                   bpo services        5
# 541                   monetization        5
# 543             data visualization        5
# 527                       hardware        5
# 415              disruptive models        5

# %% [markdown]
# __Получше, но судя по первому кластеру, тоже не очень, biotechnology and semiconductor, it and cybersecurity, oil and gas, wine and spirits в одном кластере__

# %% [markdown]
# __Попробуем openai чтобы создать словарь с категориями и создадим новую колонку в train__

# %%
category_mapping_full = {
    # Technology
    'software': 'technology',
    'mobile': 'technology',
    'biotechnology': 'technology',
    'enterprise software': 'technology',
    'saas': 'technology',
    'analytics': 'technology',
    'apps': 'technology',
    'clean technology': 'technology',
    'hardware + software': 'technology',
    'cloud computing': 'technology',
    'big data': 'technology',
    'internet': 'technology',
    'technology': 'technology',

    # Social Media & Marketing
    'social media': 'marketing',
    'advertising': 'marketing',
    'curated web': 'marketing',
    'video': 'marketing',
    'social media marketing': 'marketing',
    'facebook applications': 'marketing',
    'social crm': 'marketing',
    'ad targeting': 'marketing',
    
    # Healthcare
    'health care': 'healthcare',
    'health and wellness': 'healthcare',
    'medical': 'healthcare',
    'medication adherence': 'healthcare',
    'mhealth': 'healthcare',
    'nutrition': 'healthcare',
    'elder care': 'healthcare',
    'electronic health records': 'healthcare',
    'healthcare services': 'healthcare',
    'health services industry': 'healthcare',
    'physicians': 'healthcare',
    'doctors': 'healthcare',
    
    # Finance & Investment
    'finance': 'finance',
    'trading': 'finance',
    'risk management': 'finance',
    'billing': 'finance',
    'transaction processing': 'finance',
    'moneymaking': 'finance',
    'pre seed': 'finance',
    'hedge funds': 'finance',
    'venture capital': 'finance',
    
    # E-commerce & Retail
    'e-commerce': 'retail',
    'marketplaces': 'retail',
    'custom retail': 'retail',
    'gift registries': 'retail',
    'ticketing': 'retail',
    'wholesale': 'retail',
    'vending and concessions': 'retail',
    'auctions': 'retail',
    'groceries': 'retail',

    # Media & Broadcasting
    'broadcasting': 'media',
    'video streaming': 'media',
    'concerts': 'media',
    'tv station': 'media',
    
    # Gaming
    'games': 'gaming',
    'video games': 'gaming',
    'cloud gaming': 'gaming',
    'video game tournaments': 'gaming',
    'serious games': 'gaming',
    
    # Environment & Energy
    'energy': 'energy',
    'renewable tech': 'energy',
    'biomass power generation': 'energy',
    'oil & gas': 'energy',
    'natural resources': 'energy',
    
    # Education
    'education': 'education',
    'training': 'education',
    'language learning': 'education',
    'teaching stem concepts': 'education',
    'university students': 'education',
    
    # Business Services
    'services': 'business services',
    'public relations': 'business services',
    'field support services': 'business services',
    'direct sales': 'business services',
    'enterprise security': 'business services',
    
    # Mobility & Transport
    'mobility': 'mobility',
    'gps': 'mobility',
    'bicycles': 'mobility',

    # Fashion & Entertainment
    'fashion': 'fashion',
    'entertainment': 'arts and entertainment',
    'music venues': 'arts and entertainment',
    'film distribution': 'arts and entertainment',
    'art': 'arts and entertainment',

    # Security
    'security': 'security',
    'network security': 'security',
    'law enforcement': 'security',

    # Miscellaneous
    'technology': 'technology',
    'social investing': 'social networking',
    'collaborative consumption': 'social networking',
    'private social networking': 'social networking',
}

# %%
train['standardized_category'] = train['category_list'].apply(
    lambda categories: [category_mapping_full.get(category, category) for category in categories]
)

# %%
flattened_standardized_categories = [category for sublist in train['standardized_category'] for category in sublist]

# %%
standardized_category_counts = Counter(flattened_standardized_categories)

# %%
standardized_category_counts
# Out:
# Counter({'technology': 28809,
#          'marketing': 8185,
#          'retail': 5154,
#          'healthcare': 4790,
#          'finance': 2021,
#          'gaming': 1917,
#          'business services': 1866,
#          'education': 1794,
#          'media': 1095,
#          'manufacturing': 1080,
#          'security': 1051,
#          'arts and entertainment': 923,
#          'fashion': 832,
#          'real estate': 734,
#          'consulting': 729,
#          'travel': 724,
#          'information technology': 719,
#          'music': 676,
#          'networking': 670,
#          'search': 670,
#          'social network media': 663,
#          'news': 649,
#          'sales and marketing': 633,
#          'hospitality': 633,
#          'startups': 631,
#          'sports': 628,
#          'financial services': 611,
#          'design': 588,
#          'fintech': 588,
#          'web hosting': 576,
#          'semiconductors': 565,
#          'messaging': 540,
#          'digital media': 487,
#          'photography': 465,
#          'web development': 459,
#          'android': 457,
#          'medical devices': 439,
#          'automotive': 437,
#          'iphone': 414,
#          'events': 413,
#          'content': 401,
#          'transportation': 387,
#          'payments': 385,
#          'telecommunications': 380,
#          'consumer electronics': 374,
#          'pharmaceuticals': 373,
#          'publishing': 371,
#          'edtech': 364,
#          'collaboration': 362,
#          'location based services': 360,
#          'energy': 360,
#          'internet of things': 359,
#          'health diagnostics': 356,
#          'big data analytics': 354,
#          'b2b': 344,
#          'recruiting': 340,
#          'enterprises': 334,
#          'service providers': 332,
#          'mobile commerce': 324,
#          'consumer goods': 320,
#          'wireless': 318,
#          'brand marketing': 314,
#          'online shopping': 312,
#          'internet marketing': 305,
#          'human resources': 305,
#          'fitness': 296,
#          'reviews and recommendations': 292,
#          'ios': 290,
#          'real time': 289,
#          'social commerce': 288,
#          'restaurants': 281,
#          'crm': 279,
#          'crowdsourcing': 270,
#          'health care information technology': 268,
#          'customer service': 261,
#          'small and medium businesses': 253,
#          'mobile payments': 244,
#          'business intelligence': 242,
#          'shopping': 234,
#          'marketing automation': 232,
#          'television': 226,
#          'electronics': 226,
#          'local': 222,
#          'lifestyle': 219,
#          'hardware': 217,
#          'databases': 214,
#          'consumers': 210,
#          'application platforms': 206,
#          'communities': 205,
#          'storage': 204,
#          'finance technology': 200,
#          'computers': 199,
#          'crowdfunding': 199,
#          'machine learning': 198,
#          'mobile games': 195,
#          'logistics': 195,
#          'social networking': 189,
#          'web tools': 187,
#          'developer apis': 184,
#          'investment management': 183,
#          'photo sharing': 182,
#          'predictive analytics': 182,
#          'cloud data services': 180,
#          'productivity software': 180,
#          'information services': 179,
#          'file sharing': 176,
#          'legal': 175,
#          'social games': 174,
#          'email': 174,
#          'mobility': 171,
#          'kids': 171,
#          'seo': 170,
#          'nonprofits': 167,
#          'ipad': 167,
#          'peer-to-peer': 160,
#          'delivery': 159,
#          'wearables': 159,
#          'market research': 157,
#          'artificial intelligence': 156,
#          'public transportation': 152,
#          'banking': 149,
#          'advertising platforms': 149,
#          'beauty': 148,
#          'employment': 146,
#          'project management': 145,
#          'audio': 145,
#          'travel & tourism': 145,
#          'mobile advertising': 145,
#          'personalization': 144,
#          'open source': 143,
#          'blogging platforms': 141,
#          'data security': 139,
#          'twitter applications': 139,
#          'food processing': 137,
#          'hospitals': 137,
#          'loyalty programs': 136,
#          'environmental innovation': 136,
#          'cars': 136,
#          'retail technology': 134,
#          'data visualization': 133,
#          'nanotechnology': 132,
#          'web design': 131,
#          'lead generation': 130,
#          'colleges': 129,
#          'therapeutics': 127,
#          'insurance': 126,
#          'hotels': 126,
#          'optimization': 125,
#          'coupons': 124,
#          'online travel': 124,
#          'gamification': 123,
#          'chat': 123,
#          'development platforms': 122,
#          'career management': 122,
#          'local businesses': 120,
#          'paas': 120,
#          'bitcoin': 120,
#          'online reservations': 119,
#          '3d': 119,
#          'life sciences': 119,
#          'parenting': 118,
#          'renewable energies': 116,
#          'virtualization': 114,
#          'specialty foods': 114,
#          'solar': 112,
#          'tracking': 112,
#          'agriculture': 112,
#          'app marketing': 112,
#          'mobile software tools': 111,
#          'game': 109,
#          'accounting': 109,
#          'robotics': 107,
#          'pets': 106,
#          'mobile health': 106,
#          'discounts': 106,
#          'entrepreneur': 105,
#          'online dating': 104,
#          'data integration': 104,
#          'clean energy': 103,
#          'sensors': 103,
#          'cyber security': 103,
#          'event management': 102,
#          'energy efficiency': 102,
#          'home automation': 102,
#          'aerospace': 101,
#          'email marketing': 101,
#          'maps': 100,
#          'consumer internet': 100,
#          'wine and spirits': 99,
#          'construction': 99,
#          'personal finance': 98,
#          'online rental': 96,
#          'all students': 96,
#          'distribution': 96,
#          'professional services': 95,
#          'supply chain management': 95,
#          'voip': 94,
#          'sms': 93,
#          'outsourcing': 93,
#          'graphics': 93,
#          'gift card': 91,
#          'bio-pharm': 91,
#          'innovation management': 90,
#          '3d printing': 90,
#          'film': 90,
#          'home & garden': 90,
#          'online scheduling': 90,
#          'tablets': 89,
#          'tourism': 88,
#          'cloud infrastructure': 87,
#          'property management': 87,
#          'ediscovery': 86,
#          'communications infrastructure': 86,
#          'incentives': 86,
#          'business development': 84,
#          'e-commerce platforms': 84,
#          'freelancers': 82,
#          'document management': 81,
#          'industrial': 79,
#          'augmented reality': 78,
#          'developer tools': 78,
#          'virtual worlds': 78,
#          'point of sale': 78,
#          'cloud management': 78,
#          'creative': 77,
#          'identity': 76,
#          'promotional': 75,
#          'price comparison': 75,
#          'monetization': 74,
#          'data centers': 74,
#          'leisure': 74,
#          'local search': 74,
#          'content delivery': 74,
#          'personal health': 73,
#          'semantic search': 73,
#          'information security': 73,
#          'infrastructure': 73,
#          'women': 73,
#          'data mining': 73,
#          'diagnostics': 73,
#          'printing': 73,
#          'weddings': 72,
#          'content discovery': 72,
#          'shipping': 72,
#          'web cms': 71,
#          'online education': 70,
#          'navigation': 70,
#          'image recognition': 69,
#          'testing': 69,
#          'online gaming': 68,
#          'user experience design': 67,
#          'mobile devices': 67,
#          'water': 67,
#          'business analytics': 66,
#          'subscription businesses': 66,
#          'visualization': 66,
#          'utilities': 66,
#          'sales automation': 66,
#          'surveys': 66,
#          'sustainability': 66,
#          'oil': 65,
#          'non profit': 65,
#          'product design': 64,
#          'universities': 64,
#          'energy management': 64,
#          'k-12 education': 64,
#          'classifieds': 63,
#          'innovation engineering': 62,
#          '3d technology': 62,
#          'it management': 60,
#          'mobile security': 59,
#          'contact management': 59,
#          'cloud security': 58,
#          'tutoring': 58,
#          'drones': 58,
#          'home decor': 57,
#          'customer support tools': 57,
#          'furniture': 57,
#          'privacy': 57,
#          'green': 56,
#          'portals': 56,
#          'clinical trials': 56,
#          'jewelry': 55,
#          'cosmetics': 55,
#          'music services': 55,
#          'computer vision': 55,
#          'teachers': 55,
#          'social buying': 55,
#          'professional networking': 54,
#          'app stores': 54,
#          'systems': 53,
#          'chemicals': 53,
#          'health and insurance': 53,
#          'recycling': 53,
#          'task management': 53,
#          'commercial real estate': 53,
#          'translation': 52,
#          'video on demand': 52,
#          'stock exchanges': 51,
#          'vacation rentals': 51,
#          'politics': 51,
#          'semantic web': 50,
#          'rental housing': 50,
#          'credit': 50,
#          'educational games': 50,
#          'social recruiting': 49,
#          'business productivity': 49,
#          'gambling': 49,
#          'architecture': 48,
#          'natural language processing': 48,
#          'governments': 48,
#          'sporting goods': 48,
#          'knowledge management': 48,
#          'organic food': 47,
#          'credit cards': 47,
#          'journalism': 47,
#          'algorithms': 47,
#          'identity management': 47,
#          'toys': 47,
#          'meeting software': 47,
#          'search marketing': 47,
#          'bridging online and offline': 46,
#          'lighting': 46,
#          'digital signage': 46,
#          'charity': 46,
#          'fraud detection': 46,
#          'mobile analytics': 46,
#          'it and cybersecurity': 45,
#          'social search': 45,
#          'online video advertising': 45,
#          'textbooks': 45,
#          'social television': 44,
#          'mobile video': 44,
#          'engineering firms': 44,
#          'opinions': 44,
#          'lifestyle products': 44,
#          'entertainment industry': 44,
#          'social media platforms': 44,
#          'career planning': 44,
#          'social media monitoring': 43,
#          'social + mobile + local': 43,
#          'virtual currency': 43,
#          'incubators': 43,
#          'video conferencing': 43,
#          'communications hardware': 42,
#          'm2m': 42,
#          'content creators': 42,
#          'skill assessment': 42,
#          'e-books': 41,
#          'home renovation': 41,
#          'digital entertainment': 41,
#          'high schools': 41,
#          'nfc': 41,
#          'polling': 40,
#          'mobile social': 40,
#          'browser extensions': 40,
#          'fantasy sports': 40,
#          'product development services': 40,
#          'nightlife': 40,
#          'waste management': 40,
#          'reputation': 39,
#          'cooking': 39,
#          'farming': 39,
#          'p2p money transfer': 39,
#          'electrical distribution': 39,
#          'electric vehicles': 39,
#          'video chat': 38,
#          'recipes': 38,
#          'social media advertising': 38,
#          'artists globally': 38,
#          'social fundraising': 37,
#          'local based services': 37,
#          'industrial automation': 37,
#          'direct marketing': 37,
#          'parking': 37,
#          'embedded hardware and software': 37,
#          'flash storage': 37,
#          'advertising networks': 37,
#          'presentations': 37,
#          'alumni': 36,
#          'psychology': 36,
#          'iaas': 36,
#          'biometrics': 36,
#          'dental': 36,
#          'group buying': 36,
#          'staffing firms': 36,
#          'qr codes': 36,
#          'geospatial': 35,
#          'displays': 35,
#          'defense': 35,
#          'babies': 35,
#          'mmo games': 35,
#          'employer benefits programs': 35,
#          'text analytics': 35,
#          'new product development': 35,
#          'adventure travel': 34,
#          'guides': 34,
#          'performance marketing': 34,
#          'advice': 34,
#          'corporate training': 34,
#          'mass customization': 33,
#          'local advertising': 33,
#          'unifed communications': 33,
#          'neuroscience': 33,
#          'mobile enterprise': 33,
#          'diy': 32,
#          'interior design': 32,
#          'smart grid': 32,
#          'gadget': 32,
#          'water purification': 32,
#          'shoes': 32,
#          'medical professionals': 32,
#          'mechanical solutions': 32,
#          'celebrity': 32,
#          'soccer': 32,
#          'oil and gas': 32,
#          'shared services': 31,
#          'social media management': 31,
#          'social travel': 31,
#          'application performance monitoring': 31,
#          'public safety': 31,
#          'licensing': 30,
#          'match-making': 30,
#          'taxis': 30,
#          'synchronization': 30,
#          'craft beer': 30,
#          'outdoors': 30,
#          'forums': 29,
#          'internet service providers': 29,
#          'emerging markets': 29,
#          'internet tv': 29,
#          'intellectual property': 29,
#          'intellectual asset management': 28,
#          'consumer lending': 28,
#          'enterprise application': 28,
#          'smart building': 28,
#          'domains': 28,
#          'auto': 27,
#          'postal and courier services': 27,
#          'organic': 27,
#          'coffee': 27,
#          'virtual workforces': 27,
#          'telephony': 27,
#          'intelligent systems': 27,
#          'gas': 27,
#          'flash sales': 27,
#          'exercise': 27,
#          'wealth management': 27,
#          'designers': 26,
#          'creative industries': 26,
#          'new technologies': 26,
#          'batteries': 26,
#          'families': 26,
#          'real estate investors': 26,
#          'tech field support': 25,
#          'lead management': 25,
#          'film production': 25,
#          'interest graph': 25,
#          'diabetes': 25,
#          'brokers': 25,
#          'consumer behavior': 25,
#          'mobile shopping': 25,
#          'social business': 25,
#          'content syndication': 24,
#          'active lifestyle': 24,
#          'digital rights management': 24,
#          'online identity': 24,
#          'software compliance': 24,
#          'freemium': 24,
#          'fleet management': 24,
#          'all markets': 23,
#          'office space': 23,
#          'visual search': 22,
#          'material science': 22,
#          'mining technologies': 22,
#          'nightclubs': 22,
#          'assisitive technology': 22,
#          'proximity internet': 22,
#          'comparison shopping': 22,
#          'test and measurement': 22,
#          'advanced materials': 21,
#          'human computer interaction': 21,
#          'bioinformatics': 21,
#          'simulation': 21,
#          'enterprise search': 21,
#          'trusted networks': 21,
#          'rfid': 21,
#          'mobile coupons': 21,
#          'interface design': 21,
#          'government innovation': 21,
#          'angels': 20,
#          'photo editing': 20,
#          'financial exchanges': 20,
#          'procurement': 20,
#          'distributors': 20,
#          'social bookmarking': 20,
#          'mobile emergency&health': 20,
#          'microblogging': 20,
#          'ipod touch': 20,
#          'college recruiting': 19,
#          'sponsorship': 19,
#          'humanitarian': 19,
#          'usability': 19,
#          'franchises': 19,
#          'homeland security': 19,
#          'social entrepreneurship': 19,
#          'web browsers': 19,
#          'eyewear': 18,
#          'cannabis': 18,
#          'self development': 18,
#          'writers': 18,
#          'corporate wellness': 18,
#          'cad': 18,
#          'specialty retail': 18,
#          'linux': 18,
#          'contests': 18,
#          'video editing': 18,
#          'genetic testing': 18,
#          'home owners': 17,
#          'optical communications': 17,
#          'high tech': 17,
#          'cyber': 17,
#          'human resource automation': 17,
#          'building products': 17,
#          'windows phone 7': 17,
#          'child care': 16,
#          'collectibles': 16,
#          'speech recognition': 16,
#          'mens specific': 16,
#          'college campuses': 16,
#          'social innovation': 16,
#          'freetoplay gaming': 16,
#          'senior citizens': 16,
#          'indoor positioning': 16,
#          'automated kiosk': 16,
#          'subscription service': 16,
#          'internet radio market': 16,
#          'specialty chemicals': 16,
#          'advertising exchanges': 15,
#          'insurance companies': 15,
#          'data privacy': 15,
#          'handmade': 15,
#          'charter schools': 15,
#          'young adults': 15,
#          'vertical search': 15,
#          'email newsletters': 15,
#          'enterprise 2.0': 15,
#          'dietary supplements': 15,
#          'lasers': 15,
#          'textiles': 15,
#          'certification test': 15,
#          'english-speaking': 14,
#          'boating industry': 14,
#          'spas': 14,
#          'productivity': 14,
#          'fuels': 14,
#          'cable': 14,
#          'game mechanics': 14,
#          'teenagers': 13,
#          'veterinary': 13,
#          'q&a': 13,
#          'archiving': 13,
#          'lingerie': 13,
#          'virtual goods': 13,
#          'ventures for good': 13,
#          'sns': 13,
#          'operating systems': 13,
#          'contact centers': 13,
#          'local services': 13,
#          'ride sharing': 13,
#          'product search': 13,
#          'comics': 12,
#          'web presence management': 12,
#          'google apps': 12,
#          'baby accessories': 12,
#          'data center infrastructure': 12,
#          'recreation': 12,
#          'brewing': 12,
#          'ict': 12,
#          'realtors': 12,
#          'kinect': 12,
#          'enterprise resource planning': 11,
#          'commodities': 11,
#          'heavy industry': 11,
#          'space travel': 11,
#          'estimation and quoting': 11,
#          'data center automation': 11,
#          'social news': 11,
#          'offline businesses': 11,
#          'senior health': 11,
#          'pc gaming': 11,
#          'assisted living': 11,
#          'mac': 11,
#          'farmers market': 11,
#          'online auctions': 11,
#          'quantified self': 11,
#          'green consumer goods': 11,
#          'ebooks': 11,
#          'green building': 11,
#          'musicians': 10,
#          'internet infrastructure': 10,
#          'business information systems': 10,
#          'energy it': 10,
#          'tv production': 10,
#          'demographies': 10,
#          'early-stage technology': 10,
#          'local coupons': 10,
#          'energy storage': 10,
#          'minerals': 10,
#          'wind': 9,
#          'plumbers': 9,
#          'dod/military': 9,
#          'coworking': 9,
#          'personal data': 9,
#          'carbon': 9,
#          'physical security': 9,
#          'tea': 9,
#          'semiconductor manufacturing equipment': 9,
#          'service industries': 9,
#          'logistics company': 9,
#          'unmanned air systems': 9,
#          'edutainment': 9,
#          'b2b express delivery': 9,
#          'religion': 9,
#          'resorts': 9,
#          'high school students': 9,
#          'commercial solar': 9,
#          'local commerce': 9,
#          'graphic design': 9,
#          'flowers': 9,
#          'gift exchange': 9,
#          'gold': 9,
#          'cryptocurrency': 8,
#          'music education': 8,
#          'corporate it': 8,
#          'aquaculture': 8,
#          'enterprise hardware': 8,
#          'temporary staffing': 8,
#          'video processing': 8,
#          'limousines': 8,
#          'theatre': 8,
#          'uv leds': 8,
#          'mobile infrastructure': 8,
#          'outdoor advertising': 8,
#          'independent music labels': 8,
#          'governance': 7,
#          'charities': 7,
#          'social opinion platform': 7,
#          'cloud-based music': 7,
#          'deep information technology': 7,
#          'cosmetic surgery': 7,
#          'general public worldwide': 7,
#          'fertility': 7,
#          'civil engineers': 7,
#          'google glass': 7,
#          'retirement': 7,
#          'infrastructure builders': 7,
#          'call center automation': 7,
#          'residential solar': 7,
#          'industrial energy efficiency': 7,
#          'user interface': 7,
#          'self storage': 7,
#          'rapidly expanding': 7,
#          'mobile search': 6,
#          'watch': 6,
#          'sailing community': 6,
#          'greentech': 6,
#          'private school': 6,
#          'cause marketing': 6,
#          'musical instruments': 6,
#          'performing arts': 6,
#          'debt collecting': 6,
#          'motors': 6,
#          'registrars': 6,
#          'sextech': 6,
#          'bpo services': 6,
#          'animal feed': 6,
#          'group sms': 6,
#          'internet technology': 6,
#          'sunglasses': 6,
#          'personal branding': 6,
#          'face recognition': 6,
#          'in-flight entertainment': 6,
#          'audiobooks': 6,
#          'reading apps': 6,
#          'landscaping': 5,
#          'casual games': 5,
#          'lifestyle businesses': 5,
#          'skate wear': 5,
#          'golf equipment': 5,
#          'rim': 5,
#          'skill gaming': 5,
#          'webos': 5,
#          'app discovery': 5,
#          'indians': 5,
#          'business travelers': 5,
#          'natural gas uses': 5,
#          'console gaming': 5,
#          'impact investing': 5,
#          'user testing': 5,
#          'rehabilitation': 5,
#          'multi-level marketing': 5,
#          'diving': 5,
#          'swimming': 4,
#          'motion capture': 4,
#          'micro-enterprises': 4,
#          'nutraceutical': 4,
#          'lotteries': 4,
#          'alternative medicine': 4,
#          'pervasive computing': 4,
#          'social media agent': 4,
#          'technical continuing education': 4,
#          'biofuels': 4,
#          'disruptive models': 4,
#          'baby safety': 4,
#          'china internet': 4,
#          'concentrated solar power': 4,
#          'sports stadiums': 4,
#          'spam filtering': 4,
#          'shipping broker industry': 4,
#          'fmcg': 3,
#          'surfing community': 3,
#          'clean technology it': 3,
#          'adaptive equipment': 3,
#          'guide to nightlife': 3,
#          'independent pharmacies': 3,
#          'experience design': 3,
#          'generation y-z': 2,
#          'anything capital intensive': 2,
#          'hi tech': 2,
#          'funeral industry': 2,
#          'fruit': 2,
#          'low bid auctions': 2,
#          'niche specific': 2,
#          'hunting industry': 2,
#          'prediction markets': 2,
#          'non-tech': 2,
#          'twin-tip skis': 2,
#          'salesforce killers': 2,
#          'east africa': 2,
#          'west africa': 2,
#          'underserved children': 2,
#          'remediation': 2,
#          'virtual desktop': 2,
#          'podcast': 2,
#          'air pollution control': 2,
#          'racing': 2,
#          'south east asia': 2,
#          'utility land vehicles': 2,
#          'rural energy': 2,
#          'enterprise purchasing': 2,
#          'independent music': 2,
#          'building owners': 2,
#          'radical breakthrough startups': 2,
#          'social activists': 2,
#          'early stage it': 1,
#          'timeshares': 1,
#          'eda tools': 1,
#          'direct advertising': 1,
#          'startup histrionics': 1,
#          'quantitative marketing': 1,
#          'first aid': 1,
#          'notebooks': 1,
#          'vulnerability management': 1,
#          'made in italy': 1,
#          'private corrections': 1,
#          'labor optimization': 1,
#          'sex industry': 1,
#          'biotechnology and semiconductor': 1,
#          'fuel cells': 1,
#          'hdtv': 1,
#          'hip hop': 1,
#          'fpga': 1,
#          'baby boomers': 1,
#          'mothers': 1,
#          'invention': 1,
#          'elderly': 1})

# %% [markdown]
# __К сожалению словарь далеко не полон и у нас все также уйма категорий. Пожалуй, не будем использовать категории как входной признак для нашей модели так как с оптимизацией и аггрегацией категорий справиться не удалось__

# %% [markdown]
# __Пропуски в данных мы заполним в пайплайне обработки данных__

# %% [markdown]
# ## Исследовательский анализ данных

# %%
test.head()
# Out:
#                      name                   category_list  funding_total_usd  \
# 0              Crystalsol                Clean Technology          2819200.0
# 1        JBI Fish & Wings                     Hospitality                NaN
# 2                COINPLUS                         Finance           428257.0
# 3  Imagine Communications  Software|Video|Video Streaming         34700000.0
# 4                   DNA13                        Software          4530000.0
#
#   country_code state_code            region              city  funding_rounds  \
# 0          NIC         17               NaN               NaN               1
# 1          USA         TN        TN - Other          Humboldt               1
# 2          LUX          3  Esch-sur-alzette  Esch-sur-alzette               2
# 3          USA         CA         San Diego         San Diego               4
# 4          CAN         ON            Ottawa            Ottawa               1
#
#   first_funding_at last_funding_at  lifetime
# 0       2009-07-01      2009-07-01      3501
# 1       2010-07-28      2010-07-28      2717
# 2       2014-05-15      2014-09-18      1295
# 3       2005-01-01      2010-04-20      4748
# 4       2007-05-08      2007-05-08      6209

# %%
train.head()
# Out:
#                      name                              category_list  \
# 0               Lunchgate         [online reservations, restaurants]
# 1                 EarLens  [manufacturing, medical, medical devices]
# 2  Reviva Pharmaceuticals                            [biotechnology]
# 3    Sancilio and Company                              [health care]
# 4     WireTough Cylinders                            [manufacturing]
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds founded_at first_funding_at last_funding_at  \
# 0        Zürich               2 2009-10-17       2011-05-01      2014-12-01
# 1  Redwood City               4 2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3 2006-01-01       2012-08-20      2014-07-02
# 3           NaN               3 2004-01-01       2011-09-01      2014-07-18
# 4       Bristol               1 2010-05-12       2012-02-01      2012-02-01
#
#   closed_at                         standardized_category
# 0       NaT            [online reservations, restaurants]
# 1       NaT  [manufacturing, healthcare, medical devices]
# 2       NaT                                  [technology]
# 3       NaT                                  [healthcare]
# 4       NaT                               [manufacturing]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   52515 non-null  object
#  1   category_list          52516 non-null  object
#  2   funding_total_usd      42447 non-null  float64
#  3   status                 52516 non-null  object
#  4   country_code           47014 non-null  object
#  5   state_code             45753 non-null  object
#  6   region                 46157 non-null  object
#  7   city                   46157 non-null  object
#  8   funding_rounds         52516 non-null  int64
#  9   founded_at             52516 non-null  datetime64[ns]
#  10  first_funding_at       52516 non-null  datetime64[ns]
#  11  last_funding_at        52516 non-null  datetime64[ns]
#  12  closed_at              4917 non-null   datetime64[ns]
#  13  standardized_category  52516 non-null  object
# dtypes: datetime64[ns](4), float64(1), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
train.describe()
# Out:
#        funding_total_usd  funding_rounds                     founded_at  \
# count       4.244700e+04    52516.000000                          52516
# mean        1.824748e+07        1.740670  2008-11-04 09:44:16.196206848
# min         1.000000e+00        1.000000            1970-02-05 00:00:00
# 25%         3.360275e+05        1.000000            2006-10-01 00:00:00
# 50%         2.000000e+06        1.000000            2010-10-01 00:00:00
# 75%         1.000000e+07        2.000000            2013-01-01 00:00:00
# max         3.007950e+10       19.000000            2016-04-02 00:00:00
# std         1.871173e+08        1.374522                            NaN
#
#                     first_funding_at                last_funding_at  \
# count                          52516                          52516
# mean   2011-07-17 04:45:33.247010304  2012-06-27 16:29:42.313961472
# min              1977-05-15 00:00:00            1977-05-15 00:00:00
# 25%              2009-10-12 00:00:00            2011-02-01 00:00:00
# 50%              2012-07-23 00:00:00            2013-08-30 00:00:00
# 75%              2014-04-01 00:00:00            2014-11-17 00:00:00
# max              2015-12-05 00:00:00            2015-12-07 00:00:00
# std                              NaN                            NaN
#
#                            closed_at
# count                           4917
# mean   2012-01-16 16:14:21.012812544
# min              1983-10-06 00:00:00
# 25%              2009-09-18 00:00:00
# 50%              2012-09-15 00:00:00
# 75%              2015-04-23 00:00:00
# max              2017-10-21 00:00:00
# std                              NaN

# %%
def exploratory_analysis(df):
    num_discrete_cols = df.select_dtypes(include=[int]).columns
    num_cont_cols = df.select_dtypes(include=['float64']).columns
    
    for i in num_cont_cols:
        fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
        bins= ax1.hist(x=df[i])
        ax1.vlines(x=df[i].mean(), colors='red', ymin=bins[0].min(), ymax=bins[0].max(), label='Среднее')
        ax1.vlines(x=df[i].median(), colors='red', ymin=bins[0].min(), ymax=bins[0].max(), linestyles='--', label='Медиана')
        ax1.set_title(f'Гистограмма распределения: {i}')
        ax1.set_xlabel('Значения')
        ax1.set_ylabel('Частота')
        ax1.legend(loc='upper right', framealpha=0.3)
        
        ax2.boxplot(df[i], vert=False)
        ax2.set_title(f'Boxplot: {i}')
        ax2.set_xlabel('Значения')
        ax2.set_yticks([])
        y = np.ones_like(df[i])  
        ax2.scatter(df[i], y, color='blue', alpha=0.5, label='Значения')
        ax2.legend(loc='upper right')
        
        
        plt.show()
        
    for i in num_discrete_cols:
        sns.set(style="whitegrid")
        plt.figure(figsize=(8, 4))
        ax = sns.countplot(x=i, data=df, edgecolor="black", linewidth=1.5)
        plt.title(f'Распределение {i}')
        for p in ax.patches:
            ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5),
                        textcoords='offset points')
        plt.show()

# %%
exploratory_analysis(train)

# %% [markdown]
# __Итак__:
# - Имеем всего 2 количественных признака, дискретный кол во funding_rounds и continuous funding_total_usd
# - funding_rounds подавляющее большиство 33 489 стартапов имело 1 круг финансирования
# - funding_total_usd среднее немного меньше медианны, 1.824748e+07 против 2.000000e+06. Соответственно распределение смещено влево

# %%
my_circle = plt.Circle( (0,0), 0.7, color='white')
y = train['status'].value_counts()
x = train['status'].unique()
plt.pie(y, labels=x,autopct=lambda pct: f'{pct:.1f}%\n({int(pct/100.*sum(y))})',wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.title(f'Распределение признака "{'status'}"')
plt.show()

# %% [markdown]
# __Категориальные признаки__:
# - Целевой признак статус отображен на пайчарте. 90,6 % стартапов остались в рабочем статусе, и только 4 916 закрылись на начало 2018г.
# - Остальные категориальные признаки имеют много уникальных значений и я предлагаю создать новые синтетические признаки на их основе

# %%
train['country_code'].value_counts()

# %%
train['state_code'].value_counts()

# %%
train['region'].value_counts()

# %%
train['city'].value_counts()

# %% [markdown]
# ### Добавление признаков

# %%
test.head()

# %%
train.head()

# %% [markdown]
# __Проверим что у закрытых стартапов у всех есть дата закрытия__

# %%
train[train['status'] == 'closed']['closed_at'].isna().sum()

# %% [markdown]
# __Так как у test предоставлен только lifetime, получим аналогичную величину в train, учитывая, что отчет мы делаем на дату 2018-01-01__

# %%
train['closed_at'].fillna(pd.Timestamp('2018-01-01'), inplace=True)
train['lifetime'] = train['closed_at'] - train['founded_at']
train['lifetime'] = train['lifetime'].dt.days.astype('int64')

# %% [markdown]
# __Также создадим входной признак кол-во дней между первым и последним раундом финансирования, а еще лучше сразу добавим этот шаг в пайплайн чтобы применить на тесте__

# %%
class DateDifferenceTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, start_date_col, end_date_col, output_col, output_unit='days'):
        self.start_date_col = start_date_col
        self.end_date_col = end_date_col
        self.output_col = output_col
        self.output_unit = output_unit

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()
        X[self.output_col] = X[self.end_date_col] - X[self.start_date_col]
        
        if self.output_unit == 'days':
            X[self.output_col] = X[self.output_col].dt.days
        elif self.output_unit == 'seconds':
            X[self.output_col] = X[self.output_col].dt.total_seconds()
        elif self.output_unit == 'nanoseconds':
            X[self.output_col] = X[self.output_col].astype('int64')
        else:
            raise ValueError("output_unit must be 'days', 'seconds', or 'nanoseconds'")
        
        X[self.output_col] = X[self.output_col].astype('int64')
        return X

# %%
first_last_funding_pipe = Pipeline([
    ('date_diff', DateDifferenceTransformer(start_date_col='first_funding_at', end_date_col='last_funding_at', output_col='first_last_funding', output_unit='days')),
    
])

# %%
train = first_last_funding_pipe.fit_transform(train)

train.head()

# %% [markdown]
# __Добавим метрику GDP per Capita и Gross GDP на 2018год для стран в которых находятся стартапы__

# %%
train['country_code'].nunique()

# %%
url_per_capita = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.CD?date=2018&format=json&per_page=300"
response_per_capita = requests.get(url_per_capita)
data_per_capita = response_per_capita.json()

gdp_per_capita_data = []
for entry in data_per_capita[1]:
    country_code_2 = entry['country']['id']
    gdp_per_capita = entry['value']
    
    # Convert 2-letter code to 3-letter code using pycountry
    try:
        country_code_3 = pycountry.countries.get(alpha_2=country_code_2).alpha_3
        gdp_per_capita_data.append({'country_code': country_code_3, 'gdp_per_capita': gdp_per_capita})
    except AttributeError:
        # Skip countries that don't have a 3-letter code mapping
        continue

# Convert GDP per capita data to DataFrame
gdp_per_capita_df = pd.DataFrame(gdp_per_capita_data)

# Fetch gross GDP data for 2018 from the World Bank API
url_gross_gdp = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?date=2018&format=json&per_page=300"
response_gross_gdp = requests.get(url_gross_gdp)
data_gross_gdp = response_gross_gdp.json()

# Process gross GDP data
gross_gdp_data = []
for entry in data_gross_gdp[1]:
    country_code_2 = entry['country']['id']
    gross_gdp = entry['value']
    
    # Convert 2-letter code to 3-letter code using pycountry
    try:
        country_code_3 = pycountry.countries.get(alpha_2=country_code_2).alpha_3
        gross_gdp_data.append({'country_code': country_code_3, 'gross_gdp': gross_gdp})
    except AttributeError:
        # Skip countries that don't have a 3-letter code mapping
        continue

# Convert gross GDP data to DataFrame
gross_gdp_df = pd.DataFrame(gross_gdp_data)

# Merge GDP per capita and gross GDP data into a single DataFrame
gdp_df = pd.merge(gdp_per_capita_df, gross_gdp_df, on='country_code', how='outer')

# Merge with your train DataFrame on country_code
train = train.merge(gdp_df, on='country_code', how='left')

# %%
train.head()

# %%
train.info()

# %% [markdown]
# __Попробуем создать метрику, является ли город стартапа столицей страны__

# %%
url = "https://restcountries.com/v3.1/all"
response = requests.get(url)
country_data = response.json()

# Create a dictionary to store country_code and capital city
country_capitals = {}

# Populate the dictionary with country codes and their capitals
for country in country_data:
    try:
        # Get 3-letter country code using pycountry for consistency
        country_code = pycountry.countries.get(alpha_2=country['cca2']).alpha_3
        capital = country['capital'][0] if 'capital' in country and country['capital'] else None
        if capital:
            country_capitals[country_code] = capital
    except AttributeError:
        # Skip entries without proper country code mappings
        continue

# Display a few entries from the dictionary to verify
print({k: country_capitals[k] for k in list(country_capitals)[:5]})

# %%
def is_capital(row):
    country_code = row['country_code']
    city = row['city']
    
    # Check if the country code exists in the dictionary
    if country_code in country_capitals:
        # If city is missing, return 'no'
        if pd.isna(city):
            return 'no'
        # Check if the city matches the capital (case-insensitive comparison)
        return 'yes' if country_capitals[country_code].lower() == city.lower() else 'no'
    return np.nan  # Default to 'no' if country code or city is not in the dictionary

# Apply the function to create the 'capital' column
train['capital'] = train.apply(is_capital, axis=1)

# %%
train.head()

# %%
train.capital.value_counts()

# %% [markdown]
# __Попробуем также добавить информацию о городах, как доля GDP города от страны и Employment at place of work из отчета OECD, который нам нужно будет загрузить__

# %%
oecd_df = pd.read_csv('./OECD.CFE.EDS,DSD_FUA_ECO@DF_ECONOMY,1.0+.A.EMPW+GDP...csv')

# %%
oecd_df.head()

# %% [markdown]
# __Попробуем добавить код страны по ref area, чтобы избежать одинаковых городов в разных странах__

# %%
oecd_df.info()

# %%
def map_ref_area_to_country_code(ref_area):
    # Check if `ref_area` is already a 3-letter ISO code
    if len(ref_area) == 3 and pycountry.countries.get(alpha_3=ref_area):
        return ref_area  # It’s already an ISO 3-letter code
    
    # If `ref_area` has a custom code (e.g., ES039F), extract the first two letters
    iso2_code = ref_area[:2]
    
    # Convert ISO-2 code to ISO-3 code
    try:
        return pycountry.countries.get(alpha_2=iso2_code).alpha_3
    except AttributeError:
        return None  # Return None if country code is not found

# Apply the function to create a 'country_code' column
oecd_df['country_code'] = oecd_df['REF_AREA'].apply(map_ref_area_to_country_code)

# %%
oecd_df.head()

# %%
oecd_pivoted = oecd_df.pivot_table(index=['country_code', 'Reference area'], columns='MEASURE', values='OBS_VALUE', aggfunc='first').reset_index()

oecd_pivoted.rename(columns={'Reference area': 'city', 'EMPW':'city_empw', 'GDP':'city_gdp'}, inplace=True)

print(oecd_pivoted.head())

# %%
train = train.merge(oecd_pivoted, on=['country_code', 'city'], how='left')

# %%
train.head()

# %%
train.info()

# %% [markdown]
# __Успешно, но база oecd хранила данные только по крупным городам, в итоге около 11 000 стартапов получили эти данные__

# %% [markdown]
# __Попробуем также добавить население города. Мне удалось достать датасет на 2022 год, не 2018 год, но все же__

# %%
population = pd.read_csv('./worldcities.csv')

# %%
population.head()

# %%
population.rename(columns={'iso3':'country_code'}, inplace=True)

# %%
population.info()

# %%
population_pivoted = population.pivot_table(index=['country_code','city'], values = 'population', aggfunc='mean').reset_index()
population_pivoted.head()

# %%
train.info()

# %%
train = train.merge(
    population_pivoted[['city', 'country_code', 'population']],
    on=['city', 'country_code'], 
    how='left')
train.rename(columns={'population': 'city_population'}, inplace=True)
train.head()

# %%
train.info()

# %% [markdown]
# ## Корреляционный анализ

# %%
train.info()

# %%
df_train = train[['funding_total_usd','funding_rounds','lifetime','first_last_funding','gdp_per_capita','gross_gdp','capital', 'city_empw', 'city_gdp','city_population','status']]

# %%
numerical_columns = df_train.select_dtypes(include=[int,'float64']).columns

# %%
corr_matrix = df_train.phik_matrix(interval_cols=numerical_columns)
plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Phi_K Correlation Matrix')
plt.show()

# %% [markdown]
# __Итак__:
# - корреляционный анализ с использованием Фик, который проверяет линейные и нелинейные связи показывает высокую вероятность мультиколлинеарности между входными признаками city_population и gross_gdp. Учитывая, что gross_gdp имеет меньше пропусков, то чтож, откажемся от загруженных city_population к сожалению
# - наличие умеренной положительной связи между целевым признаком статус и входным lifetime, т.е. сколько дней компания сущетвует
# - наличие очень слабой положительной связи между целевым признаком и funding_rounds, first_last_funding , gross gdp, city_empw и city_gdp

# %% [markdown]
# ## Пайплайн и подбор и обучение моделей

# %% [markdown]
# __Попробуем выбрать признаки ниже для моделирования целевого, зафиксируем random state. Предлагаю не делить train на valid и train, а использовать всю выборку для обучения и кросс валидацию для подбора модели и параметров, скейлер возьмем StandardScaler.__

# %%
train_final = df_train[['funding_rounds',
                 'lifetime',
                 'first_last_funding',
                 'gross_gdp',
                 'city_empw', 
                 'city_gdp',
                 'status']]
train_final.reset_index(drop=True)
train_final.head()

# %%
X = train_final.drop(columns='status')
y = train_final['status']

# %%
RANDOM_STATE = 42

# %%
preprocessor = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Заполним пропуски модой
    ('scaler', StandardScaler())
])


models = {
    'RandomForest': RandomForestClassifier(class_weight='balanced', random_state=RANDOM_STATE),
    'CatBoost': CatBoostClassifier(verbose=0, random_seed=RANDOM_STATE)  
}


param_grid = {
    'RandomForest': {
        'RandomForest__n_estimators': [50, 100],
        'RandomForest__max_depth': [10, 20],
        'RandomForest__min_samples_split': [2, 5, 7]
    },
    'CatBoost': {
        'CatBoost__iterations': [100, 200],
        'CatBoost__depth': [4, 6, 10],
        'CatBoost__learning_rate': [0.1, 0.2, 0.3]
    }
}


cv = StratifiedKFold(n_splits=3)
for model_name, model in models.items():
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        (model_name, model)
    ])
    randomized_search = RandomizedSearchCV(pipeline, param_grid[model_name], cv=cv,random_state=RANDOM_STATE ,scoring='f1_weighted', n_jobs=-1)
    randomized_search.fit(X, y)

# %%
print(f"Лучшая модель и ее параметры {model_name}: {randomized_search.best_params_}")
print(f"Лучшее значение метирики F1 score для модели {model_name}: {randomized_search.best_score_}")

# %% [markdown]
# __Значение f1 равное 94.6% говорит нам о том, что модель эффекитвна в отделении классов operating и closed друг от друга лишь с небольшим количеством ошибок false positive и false negative предсказаний.__

# %% [markdown]
# ## Формирование предсказаний для тестовой выборки

# %%
test.head()

# %%
test.info()

# %% [markdown]
# __Добавим необходимые синтетические признаки для тестовой выборки__

# %%
test = first_last_funding_pipe.transform(test)

test.info()

# %%
test = test.merge(gdp_df, on='country_code', how='left')

# %%
test.info()

# %%
test = test.merge(oecd_pivoted, on=['country_code', 'city'], how='left')
test.info()

# %% [markdown]
# __Отберем нужные входные признаки и передадим данные лучшей модели и пайплайну(не забываем про imputer и Scaler) для предсказаний__

# %%
X_test = test[['funding_rounds',
                 'lifetime',
                 'first_last_funding',
                 'gross_gdp',
                 'city_empw', 
                 'city_gdp',
                 ]]
X_test.reset_index(drop=True)
X_test.head()

# %%
best_pipeline = randomized_search.best_estimator_
y_test_pred = best_pipeline.predict(X_test)

# %%
results_df = pd.DataFrame({
    'name': test['name'],
    'prediction': y_test_pred
})
results_df.info()

# %%
results_df.head()

# %%
results_df.prediction.value_counts()

# %% [markdown]
# ## Вывод

# %% [markdown]
# - В ходе выполненных работ выше удалось:
#   - выполнить предобратку данных и EDA
#   - добавить ряд дополнительных входных признаков в модель, как gross gdp by country, gdp city, city empw.
#   - выполнить корреляционный анализ данных
#   - отобрать признаки и выбрать лучшую модель и парамеры к ней (большое кол-во пропусков, особенно в метриках по городам были заполнены модами)
#   - было достигнуто значение метрики качества f1 94.6% в кросс валидации на трейне
#   - был сформирован прогноз статуса стартапов для тестовой выборки
